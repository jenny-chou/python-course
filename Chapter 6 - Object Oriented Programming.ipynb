# %% [markdown]
# # Chapter 6 - Objected Oriented Programming

# %% [markdown]
# -- *A Python Course for the Humanities by Folgert Karsdorp and Maarten van Gompel*

# %% [markdown]
# <p style="font-size:20px; color:#FF3333; font-weight:bold;">Chapter is still in DRAFT stage</p>

# %% [markdown]
# ---

# %% [markdown]
# In this chapter we will introduce a new programming paradigm: **Object Oriented Programming**. We will build an application that builds a social network and computes a graph of relations between people on Twitter. The nodes of the graph will be the twitter users, and the directed edges indicate that one speaks to another. The edges will carry a weight representing the number of times messages were sent.
#
# Given a twitter corpus, we will extract who talks to whom, and whenever a connection is found, an edge is added to our graph, or an existing edge is strenghtened.

# %% [markdown]
# Object oriented programming is a data-centered programming paradigm that is based on the idea of grouping data and functions that act on particular data in so-called **classes**. A class can be seen as a complex data-type, a template if you will. Variables that are of that data type are said to be **objects** or **instances** of that class.

# %% [markdown]
# An example will clarify things:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %% [markdown]
# Ok, several things happen here. Here we created a class Person with a function `__init__`. Functions that start with underscores are always special functions to Python which are connected with other built-in aspects of the language. The initialisation function will be called when an object of that initialised. Let's do so:

# %%
author = Person("Maarten", 30)
print("My name is " + author.name)
print("My age is " + str(author.age))
# Out:
# My name is Maarten
# My age is 30

# %% [markdown]
# Functions within a class are called **methods**. The initialisation method assigns the two parameters that are passed to variables that *belong to the object*, within a class definition the object is always represented by `self`.
#
# The first argument of a method is always `self`, and it will always point to the instance of the class. This first argument however is never explicitly specified when you call the method. It is implicitly passed by Python itself. That is why you see a discrepancy between the number of arguments in the instantiation and in the class definition.
#
#
# Any variable or methods in a class can be accessed using the period (`.`) syntax:
#
#     object.variable
#
# or:
#
#     object.method

# %% [markdown]
# In the above example we printed the name and age. We can turn this into a method as well, thus allowing any person to introduce himself/herself. Let's extend our example:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def introduceyourself(self):
        print("My name is " + self.name)
        print("My age is " + str(self.age))
        
author = Person("Maarten",30)
author.introduceyourself()
# Out:
# My name is Maarten
# My age is 30

# %% [markdown]
# Do you see what happens here? Do you understand the role of `self` and notation with the period?

# %% [markdown]
# Unbeknowst to you, we have already made use of countless objects and methods throughout this course. Things like strings, lists, sets, dictionaries are all objects! Isn't that a shock? :) The object oriented paradigm is ubiquitous in Python!

# %% [markdown]
# #### Exercise

# %% [markdown]
# Add a variable `gender` (a string) to the Person class and adapt the initialisation method accordingly. Also add a method `ismale()` that uses this new information and returns a boolean value (True/False).

# %%
#adapt the code:

class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
        
    def introduceyourself(self):
        print("My name is " + self.name)
        print("My age is " + str(self.age))
        print("My gender is " + self.gender)
        
author = Person("Maarten",30, "male")
author.introduceyourself()
# Out:
# My name is Maarten
# My age is 30
# My gender is male

# %% [markdown]
# ---

# %% [markdown]
# ### Inheritance *

# %% [markdown]
# One of the neat things you can do with classes is that you can **build more specialised classes on top of more generic classes**. `Person` for instance is a rather generic concept. We can use this generic class to build a more specialised class `Teacher`, a person that teaches a course. If you use inheritance, everything that the parent class could do, the inherited class can do as well!
#
# The syntax for inheritance is as follows, do not confuse it with parameters in a function/method definition. We also add an extra method `stateprofession()` otherwise `Teacher` would be no different than `Person`:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def introduceyourself(self):
        print("My name is " + self.name)
        print("My age is " + str(self.age))
    
    def stateprofession(self):
        print("I have no profession! :'(")
        
class Teacher(Person): #this class inherits the class above!
    def stateprofession(self):
        print("I am a teacher!")
        
class Engineer(Person): #this class inherits the class above!
    def stateprofession(self):
        print("I am an engineer!")

# %%
author = Person("Maarten",30)
author.introduceyourself()
author.stateprofession()
# Out:
# My name is Maarten
# My age is 30
# I have no profession! :'(

# %%
author = Teacher("Maarten",30)
author.introduceyourself()
author.stateprofession()
# Out:
# My name is Maarten
# My age is 30
# I am a teacher!

# %%
author = Engineer("Maarten",30)
author.introduceyourself()
author.stateprofession()
# Out:
# My name is Maarten
# My age is 30
# I am an engineer!

# %% [markdown]
# #### Exercise

# %% [markdown]
# If the class `Person` would have already had a method `stateprofession`, then it would have been overruled (we say *overloaded*) by the one in the `Teacher` class. Edit the example above, add a print like *"I have no profession! :'("* and see that nothings changes

# %% [markdown]
# ---

# %% [markdown]
# Instead of completely overloading a method, you can also call the method of the parent class. The following example contains modified versions of all methods, adds some extra methods and variables to keep track of the courses that are taught by the teacher. The edited methods call the method of the parent class the avoid repetition of code (one of the deadly sins of computer programming):

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def introduceyourself(self):
        print("My name is " + self.name)
        print("My age is " + str(self.age))
    
    def stateprofession(self):
        print("I have no profession! :'(")
        

class Teacher(Person): #this class inherits the class Person!
    def __init__(self, name, age):
        self.courses = [] #initialise a new variable
        super().__init__(name, age) #call the init of Person to initialize Person
    
    def introduceyourself(self):
        super().introduceyourself() #call the introduceyourself() of the Person
        
        self.stateprofession()
        print("I teach " + str(self.numofcourses()) + " course(s)")
        for course in self.courses:
            print("I teach " + course)
        
    def stateprofession(self):
        print("I am a teacher!")
        
    def addcourse(self, course):
        self.courses.append(course)
        
    def numofcourses(self):
        return len(self.courses)
    
    
author = Teacher("Maarten",30)
author.addcourse("Python")
author.introduceyourself()
# Out:
# My name is Maarten
# My age is 30
# I am a teacher!
# I teach 1 course(s)
# I teach Python

# %% [markdown]
# ---

# %% [markdown]
# ### Operator overloading

# %% [markdown]
# If you write your own classes, you can define what needs to happen if an operator such as for example `+`,`/` or `<` is used on your class. You can also define what happens when the keyword `in` or built-in functions such as `len()` are you used with your class. This allows for a very elegant way of programming. Each of these operators and built-in functions have an associated method which you can overload. All of these methods start, like `__init__`, with a double underscore.

# %% [markdown]
# For example. Let's allow comparison of tweets using the '<' and '>' operators. The methods for the opertors are respectively `__lt__` and `__gt__`, both take one argument, the other object to compare to. A tweet qualifies as greater than another if it is a newer, more recent, tweet:

# %%
class Tweet:
    def __init__(self, message, time):
        self.message = message
        self.time = time # we will assume here that time is a numerical value
        
    def __lt__(self, other):
        return self.time < other.time
        
    def __gt__(self, other):
        return self.time > other.time    
    

oldtweet = Tweet("this is an old tweet", 20)
newtweet = Tweet("this is a new tweet", 1000)
print(newtweet > oldtweet)
# Out:
# True

# %%
newtweet > 10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d15c839b1452> in <module>
# ----> 1 newtweet > 10
#
# <ipython-input-28-d110ea299d0c> in __gt__(self, other)
#       8
#       9     def __gt__(self, other):
# ---> 10         return self.time > other.time
#      11
#      12
#
# AttributeError: 'int' object has no attribute 'time'

# %% [markdown]
# You may not yet see much use in this, but consider for example the built-in function `sorted()`. Having such methods defined now means we can sort our tweets! And because we defined the methods `__lt__` and `__gt__` based on time. It will automatically sort them on time, from old to new:

# %%
tweets = [newtweet,oldtweet]

for tweet in sorted(tweets):
    print(tweet.message)
# Out:
# this is an old tweet
# this is a new tweet

# %%
for tweet in sorted([newtweet,oldtweet, 10]):
    print(tweet.message)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-d52e4fdeeb60> in <module>
# ----> 1 for tweet in sorted([newtweet,oldtweet, 10]):
#       2     print(tweet.message)
#
# <ipython-input-28-d110ea299d0c> in __gt__(self, other)
#       8
#       9     def __gt__(self, other):
# ---> 10         return self.time > other.time
#      11
#      12
#
# AttributeError: 'int' object has no attribute 'time'

# %% [markdown]
# #### Exercise

# %% [markdown]
# Remember the `in` keyword? Used checking items in lists and keys in dictionaries? To recap:

# %%
fruits = ['banana','pear','orange']
print('pear' in fruits)
# Out:
# True

# %% [markdown]
# Overloading this operator is done using the `__contains__` method. It takes as extra argument the item that is being searched for ('pear' in the above example). The method should return a boolean value. For tweets, let's implement support for the `in` operator and have it check whether a certain word is in the tweet.

# %%
class Tweet:
    def __init__(self, message, time):
        self.message = message
        self.time = time

    def __lt__(self, other):
        return self.time < other.time
        
    def __contains__(self, word):
        #Implement the method
        if word in self.message:
            return True
        return False

tweet = "I just flushed my toilet"
#now write code to check if the word "flushed" is in the tweet
#and print something nice if that's the case
tweet_obj = Tweet(tweet, 10)
if "flushed" in tweet_obj:
    print("\"flushed\"", "in:", tweet_obj.message)
# Out:
# "flushed" in: I just flushed my toilet

# %% [markdown]
# ---

# %% [markdown]
# ### Iteration over an object

# %% [markdown]
# Remember how we can iterate over lists and dictionaries using a for loop? To recap:

# %%
fruits = ['banana','pear','orange']
for fruit in fruits:
    print(fruit)
# Out:
# banana
# pear
# orange

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# We can do the same for our own object. We can make them support iteration. This is done by overloading the `__iter__` method. It takes no extra arguments and should be a **generator**. Which if you recall means that you should use `yield` instead of `return`. Consider the following class `TwitterUser`, if we iterate over an instance of that class, we want to iterate over all tweets. To make it more fun, let's iterate in chronologically sorted order:

# %%
class TwitterUser:
    def __init__(self, name):
        self.name = name
        self.tweets = [] #This will be a list of all tweets, these should be Tweet objects
        
    def __iter__(self):
        for tweet in sorted(self.tweets):
            yield tweet
            
    def append(self, tweet):
        assert isinstance(tweet, Tweet) #this code will check if tweet is an instance
                                        #of the Tweet class. If not, an exception
                                        #will be raised
        #append the tweet to our list
        self.tweets.append(tweet)
        
tweeter = TwitterUser("proycon")
tweeter.append(Tweet("My peanut butter sandwich has just fallen bottoms-down",4)) 
tweeter.append(Tweet("Tying my shoelaces",2)) 
tweeter.append(Tweet("Wiggling my toes",3)) 
tweeter.append(Tweet("Staring at a bird",1)) 

for tweet in tweeter:
    print(tweet.message)
# Out:
# Staring at a bird
# Tying my shoelaces
# Wiggling my toes
# My peanut butter sandwich has just fallen bottoms-down

# %% [markdown]
# #### Exercise

# %% [markdown]
# The method `__len__` is invoked when the built-in function `len()` is used. We want it to return the number of tweets a user has. Implement it in the example above and then run the following test, which should return `True` if you did well:

# %%
print(len(tweeter) == 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-b7a5169d5ee3> in <module>
# ----> 1 print(len(tweeter) == 4)
#
# TypeError: object of type 'TwitterUser' has no len()

# %%
class TwitterUser:
    def __init__(self, name):
        self.name = name
        self.tweets = [] #This will be a list of all tweets, these should be Tweet objects
        
    def __iter__(self):
        for tweet in sorted(self.tweets):
            yield tweet
    
    def __len__(self):
        return len(self.tweets)
            
    def append(self, tweet):
        assert isinstance(tweet, Tweet) #this code will check if tweet is an instance
                                        #of the Tweet class. If not, an exception
                                        #will be raised
        #append the tweet to our list
        self.tweets.append(tweet)
        
tweeter = TwitterUser("proycon")
tweeter.append(Tweet("My peanut butter sandwich has just fallen bottoms-down",4)) 
tweeter.append(Tweet("Tying my shoelaces",2)) 
tweeter.append(Tweet("Wiggling my toes",3)) 
tweeter.append(Tweet("Staring at a bird",1)) 

for tweet in tweeter:
    print(tweet.message)
# Out:
# Staring at a bird
# Tying my shoelaces
# Wiggling my toes
# My peanut butter sandwich has just fallen bottoms-down

# %%
print(len(tweeter) == 4)
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Extracting a social network of Twitter users

# %% [markdown]
# Now we will turn to the practical assignment of this chapter. The extraction of a graph of who tweets whom. For this purpose we make available the dataset [twitterdata.zip](http://lst.science.ru.nl/~proycon/twitterdata.zip) , download and extract it in a location of your choice.

# %% [markdown]
# The program we are writing will consist of three classes: `Tweet`,`TweetUser` and `TweetGraph`. `TweetGraph` will maintain a dictionary of users (`TweetUser`), these are the nodes of our graph. `TweetUser` will in turn maintain a list of tweets (`Tweet`). `TweetUser` will also maintain a dictionary in which the keys are other TweetUser instances and the values indicate the weight of the relationship. This thus makes up the edges of our graph.

# %% [markdown]
# You will not have to write everything from scratch, we will provide a full skeleton in which you have to implement certain methods. We are going to use our external editor for this assignment. Copy the below code, edit it, and save it as `tweetnet.py`. When done, run the program from the command line, passing it one parameter, the directory where the *txt files from twitterdata.zip can be found: *python3 tweetnet.py /path/to/twitterdata/*

# %%
#! /usr/bin/env python3
# -*- coding: utf8 -*-

import sys
import pyhum.preprocess


class Tweet:    
    def __init__(self, message, time):
        self.message = message
        self.time = time
        

class TwitterUser:
    def __init__(self, name):
        self.name = name
        self.tweets = [] #This will be a list of all tweets 
        self.relations = {} #This will be a dictionary in which the keys are TwitterUser objects and the values are the weight of the relation (an integer) 
    
    def append(self, tweet):
        assert isinstance(tweet, Tweet) #this is a test, if tweet is not an instance of Tweet, it will raise an Exception.
        self.tweets.append(tweet)
        
    def __iter__(self):
        #This function, a generator, should iterate over all tweets
        #<INSERT YOUR CODE HERE>
        for tweet in self.tweets:
            yield tweet        
    
    def __hash__(self):    
        # For an object to be usable as a dictionary key, it must have a hash method. 
        # Call the hash() function over something that uniquely defined this object
        # and thus can act as a key in a dictionary. In our case, the user name is 
        # good, as no two users will have the same name:          
        return hash(self.name)
    
    
    def addrelation(self, user, graph):
        if user and user != self.name: #user must not be empty, and must not be the user itself
            if user in self.relations:
                #the user is already in our relations, strengthen the bond:
                self.relations[user] += 1
            elif user in graph:                        
                #the user exists in the graph, we can add a relation!
                self.relations[user] = 1
            #if the user does not exist in the graph, no relations will be added        
        
    
    def computerelations(self, graph):
        for tweet in self:
            #tokenise the actual tweet content (use the tokeniser in preprocess!):
            #<INSERT YOUR CODE HERE>
            tokens = pyhum.preprocess.tokenise(tweet.message) 
            
            #Search for @username tokens, extract the username, and call self.addrelation()
            #<INSERT YOUR CODE HERE>
            for token in tokens:
                if token[0] == "@":
                    self.addrelation(token[1:], graph)
                    
        
    def printrelations(self):
        #print the relations, include both users and the weight
        #<INSERT YOUR CODE HERE>
        print(self.relations)
 
        
    def gephioutput(self): 
        #produce CSV output that gephi can import
        for recipient, weight in self.relations.items():
            for i in range(0, weight):
                yield self.name + "," + recipient
 
        
class TwitterGraph:
    def __init__(self, corpusdirectory):        
        self.users = {} #initialisation of dictionary that will store all twitter users. 
                        #the keys are the usernames (strings), and the values are
                        # TweetUser instances
                
        #Load the twitter corpus 
        #tip: use preprocess.find_corpusfiles and preprocess.read_corpus_file,
        #do not use preproces.readcorpus as that will include sentence segmentation
        #which we do not want
        
        #Each txt file contains the tweets of one user.
        #all files contain three columns, separated by a TAB (\t). The first column
        #is the user, the second the time, and the third is the tweetmessage itself.
        #Create Tweet instances for every line that contains a @ (ignore other lines 
        #to conserve memory). Add those tweet instances to the right TweetUser. Create
        #TweetUser instances as new users are encountered.
        
        #self.users[user], which user being the username (string), should be an instance of the
        #of TweetUser
        
        #<INSERT YOUR CODE HERE>
        filepaths = pyhum.preprocess.find_corpus_files(corpusdirectory)
        for filepath in filepaths:
            text = pyhum.preprocess.read_corpus_file(filepath)
            for line in text.split('\n'):
                if "@" in line and len(line.split('\t'))==3:
                    col = line.split('\t')
                    tweet = Tweet(col[2], col[1])
                    if col[0] in self.users:
                        self.users[col[0]].append(tweet)
                    else:                        
                        user = TwitterUser(col[0])
                        user.append(tweet)
                        self.users[col[0]] = user

            
        #Compute relations between users
        for user in self:
            assert isinstance(user,TwitterUser)
            user.computerelations(self)
    

    
    def __contains__(self, user):
        #Does this user exist?
        return user in self.users
    
    def __iter__(self):
        #Iterate over all users
        for user in self.users.values():
            yield user

    def __getitem__(self, user):    
        #Retrieve the specified user
        return self.users[user]
            

#this is the actual main body of the program. The program should be passed one parameter
#on the command line: the directory that contains the *.txt files from twitterdata.zip.

#We instantiate the graph, which will load and compute all relations
twittergraph = TwitterGraph("twitterdata/")#sys.argv[1])

#We output all relations:
for twitteruser in twittergraph:
    twitteruser.printrelations()

#And we output to a file so you can visualise your graph in the program GEPHI
f = open('gephigraph.csv','wt',encoding='utf-8')
for twitteruser in twittergraph:
    for line in twitteruser.gephioutput(): 
        f.write(line + "\n")
f.close()
# Out:
# {}
# {'magisterrex': 29, 'thesocialgamer': 12, 'otakuman5000': 4, 'nickchester': 1, 'oldgamereviewer': 1, 'jeffgerstmann': 1, 'majornelson': 1, 'therealcliffyb': 1, 'gameloft': 1, 'arstechnica': 1}
# {'hodapp': 1, 'slidetoplay': 1, 'technobuffalo': 1, 'wondroushippo': 1, 'wilw': 1}
# {}
# {}
# {'rdb_aaa': 5, 'gamespite': 19, 'craigums': 1, 'mudron': 1, 'giantbomb': 1, 'jamesmielke': 2, 'teanah': 3, 'notaxation': 1, 'jimreilly': 1, 'garywhitta': 2, 'angryjedi': 1, 'gearboxsoftware': 1, '2kgames': 1}
# {'pushsquare': 1}
# {}
# {'joystiq': 1, 'appadvice': 1, 'ja2ke': 1, 'eugaet_aux': 1, 'mdk2002': 1, 'jeffgerstmann': 2, 'majornelson': 6, 'giantbomb': 2, 'therealcliffyb': 1, 'wilw': 1, 'gearboxsoftware': 2, 'gameinformer': 3, 'fullbright': 1, 'thevowel': 1, 'gamesradar': 2, 'kotaku': 1, 'gametrailers': 1}
# {'geekpobre': 4, 'walmart_games': 2, 'therealcliffyb': 1, 'garotasgeeks': 1, 'majornelson': 6, 'rodrigoflausino': 3, 'alex_navarro': 1, 'jiguryo': 2, 'spencer_stachi': 1}
# {'seeson': 68, 'keklar': 4, 'mdk2002': 22, 'tromboneforhire': 12, 'oneofswords': 2, 'therealcliffyb': 2, 'amazongames': 1, 'maxdyckhoff': 1, 'weezul': 1, 'ilradd': 1, 'tehemopenguin': 1, 'slickdeals': 1, 'majornelson': 8, 'thevowel': 3, 'popcap_games': 1, 'geoffkeighley': 1, 'nickchester': 1, 'gameloft': 1}
# {}
# {}
# {}
# {}
# {}
# {'ibu666': 1, 'aegies': 1, 'therealcliffyb': 1}
# {'leighalexander': 8, 'mittense': 15, 'colettebennett': 4, 'nickchester': 3, 'chrisremo': 10, 'patrickklepek': 1, 'mikeyface': 3, 'kobunheat': 1, 'jimsterling': 1, 'fortninety': 1, 'jaredr': 2, 'nicholsonb': 4, 'benkuchera': 1, 'jamesmielke': 1, 'geoffkeighley': 1, 'gkokoris': 5, 'fullbright': 1, 'mituk': 4, 'alibakes': 1}
# {'wolfpupy': 1, 'leducviolet': 3}
# {'appstorewire': 1, 'thundercatsnyy': 4, 'engadget': 1}
# {'magisterrex': 14, 'jasonschreier': 2, 'giantbomb': 1, 'arstechnica': 1, 'thesocialgamer': 1, 'oldgamereviewer': 3, 'ps3maniac': 2}
# {'leighalexander': 7, 'retroremakes': 5, 'jeffcannata': 1, 'jeffgerstmann': 1, 'taswell': 1, 'engadget': 1, 'simoncarless': 1, 'infinite_ammo': 3, 'maxscoville': 2, 'the1console': 3, 'radiomaru': 1, 'notch': 3, 'mikeyface': 2, 'aegies': 2, 'nickchester': 1}
# {}
# {}
# {'_wotta': 8, 'majornelson': 4, 'dmosbon': 1, 'shoinan': 2, 'thevowel': 1, 'patlike': 1, 'evilnoob': 2, 'johnnyminkley': 1, 'mrpointyhead': 1, 'atheistium': 2, 'therealcliffyb': 1}
# {'thevowel': 1, 'majornelson': 4, 'keklar': 1, 'gameinformer': 1, 'slickdeals': 1}
# {'retroremakes': 3, 'infinite_ammo': 29, 'acarboni': 1, 'simoncarless': 2, 'tinycartridge': 1, 'the1console': 4, 'nasa': 1, 'notch': 5, 'shauninman': 1, 'stephentotilo': 1, 'megaran': 1, 'radiomaru': 1}
# {'psnstores': 5, 'aaronlinde': 3, 'nickchester': 5, 'mega64official': 1, 'therealcliffyb': 1, 'colettebennett': 1, 'insomniacgames': 1, 'geekgirldiva': 1}
# {'diplo': 1, 'aots': 1, 'majornelson': 2, 'therealcliffyb': 13, 'yugiohtas': 6, 'radiomaru': 10, 'jeffgerstmann': 1, 'thegame': 1, 'geoffkeighley': 6, 'patrickklepek': 2}
# {}
# {'majornelson': 1}
# {'stroughtonsmith': 5, 'stillgray': 8, 'gamepro': 1, 'angryjedi': 3, 'brainygamer': 1, 'justinmcelroy': 1, 'mattgemmell': 5, 'notch': 1, 'fullbright': 2, 'eurogamer_net': 1}
# {'mudron': 11, 'greenspeak': 1, 'gamespite': 1, 'sterling_m': 1, 'justinmcelroy': 1, 'jwhdavison': 1, 'ferricide': 1, 'leighalexander': 3, 'andrewpfister': 1, 'fiddlecub': 2, 'taswell': 7, 'gameovergreggy': 1, 'jimreilly': 2, 'teanah': 1, 'patrickklepek': 1}
# {}
# {'artemio': 2, 'akirareiko': 38, 'renzosh': 35, 'the1console': 2, 'monch3': 3, 'punisheriv': 6, 'jamesmielke': 1, 'acarboni': 1}
# {'geekgirldiva': 10, 'nickchester': 2, 'jeremymeyers': 2, 'seeson': 2, 'mdk2002': 1, 'godfree': 1, 'gameloft': 1, 'marvel': 1}
# {'cthagod': 2, 'slickdeals': 4, 'crhopkins': 14, 'rampage198': 1, 'ps3fanboy': 14, 'robby1051': 1, 'therealcliffyb': 2, 'amazongames': 5, 'majornelson': 2, 'jimreilly': 1, 'edgeonline': 1, 'eurogamer_net': 1, 'thevowel': 1, 'insomniacgames': 1}
# {}
# {}
# {}
# {'sirchamallow': 7}
# {'capsulecomputer': 6, 'boomeranggames': 17, 'therealcliffyb': 2, 'reviewanygame': 1, 'insertcointees': 2, 'eurogamer_net': 2, 'thegamefanatics': 1, 'hentei009': 1, 'guardiantech': 1}
# {'joystiq': 1, 'kochmedia_es': 2, 'ecetia': 2, 'majornelson': 1, 'bau_er': 1, 'revogamers': 1, 'kroniksan': 1, 'zavvies': 1}
# {'earcos': 9, 'radiomaru': 1, 'renzosh': 9, 'majornelson': 1, 'jdrm': 1, 'the1console': 1, 'memohiervas': 1, 'monch3': 1}
# {}
# {'5minutesformom': 2, 'momtv': 1}
# {}
# {'jackalltimelow': 12}
# {'monch3': 5, 'therealcliffyb': 1, 'wilw': 1}
# {'iplaywinner': 3, 'shoryukendotcom': 10, 'therealcliffyb': 2, 'kotaku': 1, 'potatohead': 1}
# {'jeffgerstmann': 9, 'taswell': 14, 'patrickklepek': 8, 'jasonschreier': 2, 'aegies': 5, 'stephentotilo': 2, 'mudron': 2, 'giantbomb': 2, 'jaredr': 2, 'crecenteb': 1, 'leighalexander': 4, 'kobunheat': 2, 'garywhitta': 7, 'colettebennett': 1, 'therealcliffyb': 1, 'geoffkeighley': 2, 'nickchester': 1, 'hiphopgamer': 1, 'benkuchera': 1}
# {'hiphopgamer': 4, 'mdk2002': 7, 'justinmcelroy': 3, 'leighalexander': 1, 'theshums': 2, 'geoffkeighley': 1, 'colettebennett': 1, 'therealcliffyb': 1, 'fragdolls': 1}
# {}
# {}
# {'kzarr': 1, 'aots': 1}
# {'amazongames': 31, 'nickiminaj': 1}
# {'majornelson': 1, 'timseppala': 1, 'therealcliffyb': 2, 'gearboxsoftware': 1}
# {}
# {'therealjuicyj': 1}
# {'pushsquare': 1}
# {}
# {}
# {}
# {'joystiq': 1, 'aaronlinde': 6, 'colettebennett': 4, 'kobunheat': 2, 'aegies': 3, 'nicholsonb': 1, 'psnstores': 1, 'majornelson': 1, 'jamesmielke': 3, 'notaxation': 1, 'gameinformer': 1, 'fiddlecub': 1, 'therealcliffyb': 1, 'crecenteb': 1, 'giantbomb': 1}
# {'cherylp59': 1, 'ukgamedeals': 1, 'gameloft': 1, 'chris_woodgate': 4, 'v82chris': 1, 'lisanorfolk': 1, 'dancer2712': 2, 'clareandtribe': 1, 'redroses4': 1, 'jamesdpaton': 1, 'buzylizzy1': 1, '_wotta': 1}
# {'rdb_aaa': 2, 'patrickklepek': 21, 'kobunheat': 1, 'taswell': 3, 'amazongames': 1, 'brainygamer': 1, 'johntv': 3, 'jamesmielke': 3, 'feitclub': 1, 'jeffcannata': 4, 'mudron': 2, 'ferricide': 2, 'sterling_m': 2, 'jasonschreier': 2, 'timseppala': 1, 'giantbomb': 1}
# {'gameinformer': 30, 'jeffgerstmann': 1, 'insomniacgames': 1, 'jwhdavison': 1, 'aegies': 1, 'mdk2002': 1, 'bradgallaway': 1, 'majornelson': 1, 'geoffkeighley': 3, 'colettebennett': 6, 'therealcliffyb': 11, 'andrewpfister': 3, 'danryckert': 2, 'mikeyface': 1, 'jeffcannata': 1, 'timseppala': 1, 'nicholsonb': 1, 'alibakes': 1}
# {}
# {}
# {'earcos': 1}
# {'5minutesformom': 1, 'momsfocus': 1, 'madly59': 1, 'breakingnews': 1}
# {'populargaming': 1, 'msmorev': 16}
# {}
# {'gamepro': 4, 'ultrabrilliant': 4, 'asatiir': 4, 'schillingc': 7, 'jwhdavison': 5, 'kierongillen': 2, 'stillgray': 1, 'ferricide': 2, 'leighalexander': 4, 'justinmcelroy': 1, 'theshums': 1, 'shoinan': 4, 'adurdin': 3, 'retroremakes': 1, 'jeffgrubb': 2, 'jamesmielke': 2, 'willeth': 1, 'johnnyminkley': 1, 'benparfitt': 1, 'werezompire': 1, 'kobunheat': 1, 'jasonschreier': 1, 'majornelson': 1, 'lbd_nytetrayn': 1, 'atheistium': 1, 'pocketgamer': 1, 'mittense': 1, 'fiddlecub': 1, 'wilw': 1}
# {'mikeyface': 2, 'totalbiscuit': 1, 'gearboxsoftware': 1}
# {'aots': 5, 'jbnet211': 1, 'wilw': 12, 'majornelson': 2, 'therealcliffyb': 3, 'danawhite': 1, 'petercoffin': 2}
# {'magisterrex': 2, 'nickhalme': 1, 'seeson': 1, 'samversionone': 1, 'ryanpthompson': 1, 'gamingangel': 1, 'therealcliffyb': 1, 'giantbomb': 1, 'wilw': 1}
# {}
# {'notch': 18, 'infinite_ammo': 6, 'acarboni': 1, 'retroremakes': 2, 'joystiq': 1}
# {'fullbright': 7, 'britishgaming': 5, 'ja2ke': 2, 'edgeonline': 2, 'patrickklepek': 1, 'eurogamer_net': 2, 'radiomaru': 1, 'leighalexander': 1, 'chrisremo': 2, 'simonparkin': 1, 'johnnyminkley': 2}
# {'godfree': 19, 'gamingangel': 1, 'ladyluck34': 3, 'peterocc': 4, 'bakedant': 8, 'jbhuskers': 3, 'sergiodaprokkz': 1, 'gameinformer': 1, 'hiphopgamer': 2, 'thevowel': 1, 'wesphillips': 1, 'juggalon9ne': 1, 'gamestopcanada': 4, 'majornelson': 4, 'danawhite': 1, 'samversionone': 1}
# {'jbnet211': 1}
# {'sirhellsing420': 1}
# {}
# {'ispazio': 1, 'gameloft': 1, 'viticci': 1}
# {'razorianfly': 5, 'viticci': 10, 'hodapp': 1}
# {}
# {'148apps': 40}
# {'engadget': 1}
# {}
# {}
# {}
# {'leyeti': 1}
# {'vikingvessel': 1, 'gameloft': 3}
# {}
# {}
# {}
# {}
# {}
# {'bertrand_amar': 1, 'notch': 1, 'leyeti': 1, 'damonx': 1}
# {}
# {}
# {'danawhite': 3}
# {'kweenie': 1, 'kyleorl': 1, 'benkuchera': 3}
# {'akirareiko': 46, 'aftasher': 10, 'renzosh': 14, 'jake74': 1, 'gamespite': 2, 'shoryukendotcom': 1, '1up': 1, 'edgeonline': 1, 'gameplanet_mex': 1, 'engadget': 1}
# {'duckydynamo': 7}
# {'cowboybibimbop': 1, 'gamingangel': 3, 'alibakes': 2, 'thevowel': 2, 'geekgirldiva': 3, 'agent_m': 1, 'stillgray': 1, 'magisterrex': 1, 'mlgpro': 1}
# {'0919x': 1}
# {'angryjedi': 10, 'leighalexander': 1, 'kobunheat': 1, 'andrewpfister': 1, 'aegies': 1, 'rdb_aaa': 2, 'jamesmielke': 1}
# {'manveerheir': 1}
# {}
# {'colettebennett': 4, 'sonicalpha': 1, 'shoinan': 2, 'ultrabrilliant': 2, 'angryjedi': 2, 'schillingc': 3, 'patlike': 2, 'ignuk': 1, 'gamespotuk': 2, 'britishgaming': 1, 'stillgray': 1, 'yamstersg': 1, 'leighalexander': 1}
# {'cnnbrk': 1, 'alex_navarro': 2, 'wilw': 9, 'giantbomb': 1}
# {'buschgardens': 1}
# {'retroremakes': 1, 'jimsterling': 1, 'leighalexander': 2}
# {'jake_w': 4, 'darylsurat': 1, 'samversionone': 1, 'downsouthtigger': 1, 'gnitro': 1}
# {'brentalfloss': 2}
# {'gameloft': 3, 'appshopper': 302}
# {}
# {'totalbiscuit': 1, 'toymachinesh': 1}
# {'the_ironsheik': 1, 'johncena': 3}
# {'justin7974': 20}
# {'akirareiko': 34, 'earcos': 15}
# {'zavvies': 3, 'clopezi': 2, 'akihabarablues': 1, 'tecmokoeieurope': 1}
# {'mattandre': 1, 'notch': 1}
# {'godfree': 19, 'peterocc': 15, 'samversionone': 7, 'ladyluck34': 5, 'majornelson': 3, 'tromboneforhire': 3, 'jvb': 2, '2kgames': 1, 'cthagod': 1, 'cnnbrk': 1, 'hiphopgamer': 1}
# {}
# {'houseofanansi': 20, 'cbcbooks': 6, 'cbcradio': 2}
# {'madly59': 4, 'msmorev': 4, 'reviewanygame': 5, 'dinaj': 1, 'capsulecomputer': 7}
# {}
# {'zavvies': 2, 'ecetia': 2, 'kroniksan': 1}
# {'leighalexander': 15, 'nickchester': 1, '1up': 4, 'stillgray': 1, 'aegies': 4, 'kobunheat': 1, 'justinmcelroy': 6, 'giantbomb': 1, 'jamesmielke': 1, 'taswell': 1, 'mega64official': 1, 'fullbright': 1, 'rdb_aaa': 1, 'angryjedi': 3, 'jwhdavison': 1, 'auntiepixelante': 1, 'gamepro': 1, 'the_katbot': 1, 'kierongillen': 1, 'jeffgrubb': 1}
# {}
# {'attractions': 8, 'buschgardens': 1, 'viticci': 1}
# {'cnnbrk': 1, 'stillgray': 9, 'bajopants': 1, 'elizabethdanger': 1, 'serrels': 1, 'unklerupert': 1, 'majornelson': 1}
# {'justinmcelroy': 4, 'nicholsonb': 3, 'nickchester': 3, 'thevowel': 3, 'bradgallaway': 1, 'pushsquare': 1, 'godfree': 1, 'gameinformer': 1, 'geoffkeighley': 2, 'jimreilly': 1, 'colettebennett': 2, 'jeffgerstmann': 1, 'kobunheat': 6, 'leighalexander': 3, 'timseppala': 1, 'chrisremo': 1, 'sidshuman': 3, 'wilw': 1, 'kewlrats': 1, 'aaronlinde': 1, 'kierongillen': 1, 'mike_acton': 1, 'arstechnica': 2, 'jasonschreier': 2, 'taswell': 1, 'kweenie': 1, 'majornelson': 1, 'hiphopgamer': 1}
# {'yamstersg': 1, 'atheistium': 1}
# {'_wotta': 6, 'dmosbon': 7, 'richard4481': 3, 'johnnyminkley': 13, 'pushsquare': 1, 'britishgaming': 2, 'schillingc': 5, 'patlike': 8, 'ukgamedeals': 2, 'ultrabrilliant': 2, 'ratsoalbion': 1, 'atheistium': 2, 'yamstersg': 1}
# {'gamekult': 3}
# {}
# {'crecenteb': 1, 'fallout': 3, 'craigums': 2, 'jwhdavison': 1, 'insomniacgames': 4, 'gamepro': 2, 'eurogamer_net': 4, 'geoffkeighley': 1, 'majornelson': 4, 'cvg_uk': 1, 'therealcliffyb': 1, 'kotaku': 4, 'joystiq': 1, '1up': 3, 'gameinformer': 3, 'johnnyminkley': 1, 'darkhorsecomics': 3, 'patrickklepek': 1, 'gametrailers': 4, 'gamestop': 1, 'engadget': 1, 'giantbomb': 2, 'wilw': 1, 'gamasutra': 1, 'machinima_com': 1, 'arstechnica': 1}
# {}
# {'gameloft': 1, 'majornelson': 3, 'aegies': 4, 'garywhitta': 5, 'notch': 1, 'ilradd': 1, 'atheistium': 4, 'thevowel': 3, 'bradgallaway': 1, 'giantbomb': 1, 'therealcliffyb': 1, 'jwhdavison': 1}
# {'ihatequotes': 1, 'aots': 1, 'gnitro': 1}
# {'erogappa': 1}
# {'memohiervas': 24, 'resetmx': 13, 'spartan9216': 1, 'robsainz': 7, 'diipad': 1, 'playstationmex': 1, 'elpixelilustre': 1, 'polux_3': 1}
# {}
# {'ryanpthompson': 1, 'cashsavings': 1}
# {'gamestop': 1, 'applenws': 1, 'gamasutra': 1, 'gameinformer': 1}
# {'akihabarablues': 11, 'gamesajare': 2, 'clopezi': 9, 'quemandoacromo': 1, 'nosologeeks': 1, 'jakesplaceps': 1, 'n4g': 1, 'cvg_uk': 1, 'pslifestyle': 1, 'dagamuten': 1, 'darthkafka': 1, 'bad_spencer': 1, 'kroniksan': 1, 'zavvies': 1, '1up': 3, 'appadvice': 1, 'gamasutra': 9, 'gameloft': 2, 'edgeonline': 3, 'vidaextra': 6, 'eurogamer_net': 5, 'elpixelilustre': 1, 'insomniacgames': 1, 'popcap_games': 1, 'majornelson': 3, 'giordanobc': 1}
# {'razorianfly': 16, 'sstaver': 8, 'christyxcore': 8, 'codinghorror': 1}
# {'izzynobre': 1, 'bqeg': 1, 'r0cc0': 21, 'oimperador': 4, 'marcorigobelli': 2, 'ibere': 1, 'omelete': 1}
# {'charltonbrooker': 1}
# {'turtlegirl73': 1, 'eurogamer_net': 4, 'aceybongos': 1, 'majornelson': 2}
# {'izzynobre': 27, 'cnnbrk': 1}
# {'cthagod': 3, 'nickiminaj': 1}
# {}
# {'izzynobre': 63, 'utops': 3, 'ianblack': 1}
# {'werezompire': 2, 'shoinan': 5, 'fullbright': 2, 'kweenie': 1, 'wilw': 1, 'stillgray': 4, 'ratsoalbion': 1, 'acarboni': 1, 'jasonschreier': 1, 'timseppala': 2, 'jamesmielke': 1, 'kierongillen': 1, 'psnstores': 1, 'aaronlinde': 1}
# {'radiomaru': 7, 'paniq': 1, 'diplo': 1, 'wilw': 1}
# {'manveerheir': 7, 'stillgray': 5, 'gamasutra': 2, 'fullbright': 8, 'patrickklepek': 5, 'bradgallaway': 12, 'chrisremo': 4, 'shoinan': 1, 'leighalexander': 8, 'jasonschreier': 1, 'stephentotilo': 3, 'simoncarless': 4, 'kotaku': 1, 'mittense': 1, 'gamecouch': 1, 'amazongames': 1}
# {}
# {'markknoller': 3, 'cnnbrk': 1}
# {'gamesradar': 2, 'cantista': 4, 'geoffkeighley': 1, 'kobunheat': 2, 'ferricide': 1, 'sidshuman': 1}
# {'justinmcelroy': 1, 'alibakes': 1, 'joystiq': 1, 'capsulecomputer': 1, 'majornelson': 1}
# {'grumpy1970': 5, 'gameloft': 1, 'alongcamemary1': 2, 'downsouthtigger': 1, 'slickdeals': 2, 'capsulecomputer': 3, 'timseppala': 1, 'donnak4': 1, 'fragdolls': 1, 'thegamefanatics': 1}
# {'toymachinesh': 6, 'gameinformer': 2, 'alex_navarro': 1, 'therealcliffyb': 1, 'danawhite': 2, 'hiphopgamer': 2, 'majornelson': 1, 'ochocinco': 1, 'nickchester': 1, 'taswell': 1}
# {}
# {'bradgallaway': 1, 'aegies': 2, 'ferricide': 1, 'kobunheat': 1, 'brainygamer': 1, 'leighalexander': 1, 'robertflorence': 1, 'fullbright': 1, 'fragdolls': 1}
# {'shoinan': 5, 'the1console': 4, 'yamstersg': 2, 'ultrabrilliant': 7, 'kobunheat': 1, 'geoffkeighley': 1, 'patlike': 2, 'atheistium': 2, 'schillingc': 3, 'stillgray': 2, 'therealcliffyb': 1, 'ja2ke': 1, 'bradgallaway': 1}
# {'leighalexander': 5, 'stillgray': 19, 'terrypaton1': 2, 'notch': 5, 'bajopants': 1, 'brainygamer': 3, 'mittense': 3, 'therealcliffyb': 3, 'charltonbrooker': 1}
# {'cejbrasil': 1, 'izzynobre': 16}
# {'joystiq': 1, 'geoffkeighley': 1, 'insomniacgames': 1}
# {'therealcliffyb': 6, 'geoffkeighley': 1, '1up': 2}
# {}
# {}
# {'izzynobre': 1, 'naointendo': 1}
# {'attractions': 5, 'behindthrills': 7}
# {}
# {'codemasters_jp': 1, 'ycd': 2}
# {}
# {'andiecaz': 3, 'redroses4': 1, 'sweetzilla': 1, 'dannclan': 1, 'gamespotuk': 1, 'capsulecomputer': 6, 'dancer2712': 1}
# {'krismactavish': 1, 'el_gr': 1}
# {}
# {'r0cc0': 20, 'izzynobre': 1, 'marcorigobelli': 17, 'geekpobre': 7, 'filipekiss': 8, 'utops': 5, 'stephanmartins': 1, 'didiraja': 6, 'iltonjr': 1, 'therealcliffyb': 2, '350ml': 2, 'pabloprime': 2, 'gustavopetro': 1, 'jiguryo': 4, 'rodrigoflausino': 1, 'jurandirfilho': 3, 'tiagosantana': 1, 'leighalexander': 1}
# {'majornelson': 1, 'totalgaming': 1, 'godfree': 1, 'technobuffalo': 3, 'aots': 2, 'sesho1': 1, 'ladyluck34': 1, 'stillgray': 1, 'memohiervas': 1, 'roro': 1, 'hentei009': 1, 'calz88': 1, 'carraman': 1, 'hotreleasestuff': 1}
# {'johnnyminkley': 1, 'patlike': 2, 'godfree': 2, 'shoptonet': 4, '_wotta': 2, 'yamstersg': 1, 'ukgamedeals': 1, 'insertcointees': 2, 'engadget': 1}
# {'tierragamer': 1, 'crixlee': 1}
# {'taswell': 2, 'garywhitta': 1, 'jeffgerstmann': 1, 'wilw': 1, 'mlb': 1}
# {'ufc_brasil': 14, 'ufc': 3, 'danawhite': 1, 'ianblack': 1}
# {'pipomantis': 1, 'netsabes': 1, 'leyeti': 1, 'fullbright': 1}
# {'sexstrology': 2}
# {'notch': 1}
# {'oneofswords': 1, 'brelston': 2, 'notch': 1, 'acarboni': 1, 'gamesradar': 1, 'kotaku': 1, 'garywhitta': 1}
# {'gamesradar': 1, 'majornelson': 4, 'setsuna_quanta': 1, 'taswell': 1, 'jwhdavison': 1, 'greenspeak': 1, 'gameinformer': 1, '1up': 1, 'amazongames': 1}
# {}
# {'ea': 3, 'gameloft': 9, 'dinaj': 1, 'therealcliffyb': 3, 'majornelson': 2, 'popcap_games': 3, 'capcom_unity': 3, 'ubisoft': 3, 'thevowel': 3, 'mdk2002': 1, 'eurogamer_net': 1, 'ukgamedeals': 1}
# {'joystiq': 1, 'akirareiko': 2, 'funnyorfact': 2}
# {}
# {'renzosh': 5, 'akirareiko': 4, '_habacuc': 1, 'majornelson': 3, 'therealcliffyb': 1}
# {'cinex_noticias': 1}
# {}
# {'_wotta': 3, 'thevowel': 1, 'cnnbrk': 4, 'majornelson': 5, 'mrpointyhead': 2, 'deltorro': 1}
# {'robsainz': 4, 'renzosh': 1, 'gameplanet_mex': 1}
# {'cbcradio': 7, 'houseofanansi': 2}
# {'cbcbooks': 20}
# {'cowboybibimbop': 6, 'notch': 2, 'the_moviebob': 2}
# {}
# {}
# {'godfree': 1, 'craigums': 2, 'majornelson': 6, 'timseppala': 2, 'skrammas': 1, 'aots': 8, 'notch': 1, 'mdk2002': 1, 'therealcliffyb': 11, 'jasonschreier': 1, 'thevowel': 2, 'funnyorfact': 8, 'joystiq': 1, 'guardiantech': 1}
# {}
# {'wilw': 1, 'garywhitta': 3, 'kotaku': 2}
# {'sony': 1}
# {'geoffkeighley': 2, 'colettebennett': 9, 'nickchester': 4, 'brentalfloss': 1, 'filthierich': 1}
# {'robertflorence': 13, 'unklerupert': 1, 'schillingc': 1, 'glinner': 1, 'kierongillen': 1}
# {'saintsrow': 2, 'crecenteb': 2, 'justinmcelroy': 2, 'jamesmielke': 9, 'ukgamedeals': 4, 'hiphopgamer': 3, 'nickchester': 9, 'amazongames': 1, 'thevowel': 1, 'likchan': 1, 'jeffgerstmann': 2, 'joystiq': 1, 'patlike': 1, 'johntv': 6, 'samitsarkar': 1, 'metacritic': 1, 'benkuchera': 2, 'aegies': 1, 'garnettlee': 1}
# {'aegies': 1, 'giantbomb': 1, 'seeson': 4, 'gamestop': 1, 'cnnbrk': 28, 'thevowel': 1, 'geoffkeighley': 2, 'majornelson': 1, 'gameinformer': 2, 'teanah': 1}
# {'shoryukendotcom': 2, 'jaredr': 1, 'therealcliffyb': 1, 'tetrisdork': 2, 'giantbomb': 1, 'amazongames': 1, 'joystiq': 1, 'kylehebert': 1}
# {'codinghorror': 1}
# {'clareandtribe': 1, 'v82chris': 3}
# {}
# {'naruedyoh': 12, 'clopezi': 1, 'tecmokoeieurope': 17, 'caminante_x': 2, 'revogamers': 1, 'zavvies': 1}
# {}
# {'majornelson': 1, 'monch3': 4}
# {'leighalexander': 3, 'ja2ke': 30, 'stephentotilo': 1, 'fullbright': 31, 'ferricide': 1, 'kobunheat': 1, 'mittense': 3, 'garywhitta': 2, 'patrickklepek': 5, 'gameinformer': 1, 'aaronlinde': 2, 'jeffgerstmann': 1, 'jasonschreier': 1, 'brainygamer': 1}
# {'aots': 1, 'ochocinco': 1, 'cthagod': 1}
# {'freestylesteve': 141, 'ochocinco': 1, 'ihatequotes': 3}
# {'wilw': 1, 'stillgray': 29, 'adamatomic': 1, 'gameinformer': 2, 'mike_acton': 26, 'manveerheir': 8, 'notch': 5, 'infinite_ammo': 1, 'gamasutra': 3, 'geoffkeighley': 1, 'ja2ke': 1, 'leighalexander': 5, 'simoncarless': 2, 'eurogamer_net': 1, 'retroremakes': 1, 'dudieboy': 1, 'giantbomb': 1, 'kweenie': 1, 'mittense': 1, 'johntv': 1, 'jasonschreier': 1, 'ferricide': 1, 'therealcliffyb': 2, 'insomniacgames': 2, 'patrickklepek': 1, 'digital_foundry': 1}
# {'wilw': 3, 'razorianfly': 18, 'macstoriesnet': 1}
# {'therealcliffyb': 22, 'johnnyminkley': 3, 'thetrout91': 1, 'robertflorence': 1, 'ultrabrilliant': 1, 'godfree': 1, 'stephentotilo': 2, 'jimreilly': 3, 'geoffkeighley': 2, 'gamestopcanada': 1, 'cnnbrk': 2, 'thevowel': 1, 'nickchester': 1, 'garywhitta': 1, 'crecenteb': 1, 'majornelson': 1, 'engadget': 1}
# {'mikeyface': 1, 'gameinformer': 2}
# {'v82chris': 3, 'jamesdpaton': 2, 'dancer2712': 3, 'cobbiecollinge': 1, 'andiecaz': 1, 'buzylizzy1': 1, 'ukgamedeals': 1, 'boomeranggames': 3}
# {}
# {'filthierich': 1, 'majornelson': 3, 'godfree': 1, 'keklar': 1, 'eugaet_aux': 2, 'insertcointees': 1, 'marvel': 1, '1up': 1, 'downsouthtigger': 1, 'thevowel': 1, 'ctrlaltkill': 8, 'psnstores': 1, 'capsulecomputer': 1, 'gamestopcanada': 1}
# {'jasonschreier': 2, 'wilw': 1}
# {}
# {}
# {'duckydynamo': 1, 'wilw': 1}
# {}
# {'johnnyminkley': 14, 'toymachinesh': 25, '1up': 6, 'mikeyface': 1, 'eurogamer_net': 11, 'therealcliffyb': 8, 'majornelson': 9, 'thevowel': 5, 'ukgamedeals': 3, 'alex_navarro': 3, 'joystiq': 3, 'geoffkeighley': 3, 'gamespotuk': 5, 'charltonbrooker': 2, 'kotaku': 1, 'cnnbrk': 1, 'insomniacgames': 3, 'boomeranggames': 1, 'notch': 2, 'nickchester': 1, 'gameinformer': 1, 'seeson': 1, 'patlike': 1}
# {'wilw': 4, 'thevowel': 1, 'godfree': 3, 'crixlee': 5, 'therealcliffyb': 3, 'samversionone': 2, 'cnnbrk': 1, 'majornelson': 3, 'escoblades': 1, 'fragdolls': 2, 'seeson': 1, 'tromboneforhire': 1}
# {'capsulecomputer': 9, 'gamespotuk': 1, 'dancer2712': 1, 'tecmokoeieurope': 2, 'lisanorfolk': 1}
# {'popcap_games': 1}
# {'crunchgear': 2, 'gamasutra': 2, 'joystiq': 1}
# {'akihabarablues': 1}
# {'appadvice': 1, 'c0074gd': 2}
# {'arstechnica': 1, 'mlb': 1}
# {'charltonbrooker': 1, 'oldgamereviewer': 1, 'geoffkeighley': 1, 'the_ironsheik': 1}
# {'arstechnica': 1}
# {'gameloft': 2, 'insertcointees': 1, 'gamespotuk': 2}
# {}
# {'erogappa': 1, 'odasaga3': 2}
# {'flashpointgame': 2, 'edgeonline': 1, 'codemasters_jp': 2, 'atheistium': 1}
# {}
# {'giantbomb': 6, 'gameinformer': 1, 'spillcrew': 2, 'therealcliffyb': 1, 'jaredr': 5, 'radiomaru': 3, 'popcap_games': 2, 'taswell': 7, 'jeffgerstmann': 4, 'eidrag': 1, 'garywhitta': 1}
# {'leighalexander': 21, 'atheistium': 2, 'nickchester': 8, 'nicholsonb': 8, 'gamasutra': 1, 'aaronlinde': 2, 'chrisremo': 2, 'chad_concelmo': 1, 'tinycartridge': 1, 'simoncarless': 1, 'samitsarkar': 1, 'joystiq': 2, 'manveerheir': 1, 'giordanobc': 1, 'godfree': 4}
# {}
# {'marvel': 1}
# {'guardiantech': 1}
# {}
# {}
# {'harryallen': 1}
# {'johnnyminkley': 7, 'calz88': 1, 'samversionone': 1, 'majornelson': 5, 'tinycartridge': 2, 'edgeonline': 9, 'guycocker': 3, 'eurogamer_net': 4, 'schillingc': 1, 'crecenteb': 2, 'guardiantech': 4, 'robertflorence': 2, 'ukgamedeals': 1, 'insertcointees': 4, 'joystiq': 15, 'engadget': 2, 'gameinformer': 2, 'atheistium': 2, 'mrpointyhead': 2, 'jimreilly': 1, 'wesharegaming': 1}
# {}
# {'platinumgames': 2, 'tecmokoeieurope': 1, 'therealcliffyb': 1}
# {'notch': 1}
# {'mattgemmell': 26, 'stroughtonsmith': 1, 'charltonbrooker': 3, 'retroremakes': 1}
# {'therealcliffyb': 2, 'joystiq': 1, 'daveoshry': 1}
# {'appshopper': 3, 'razorianfly': 1, 'magisterrex': 2, 'gameloft': 1}
# {'kierongillen': 4, 'jaredr': 2, 'majornelson': 4, 'kotaku': 10, 'chrisremo': 1, 'kewlrats': 2, 'therealcliffyb': 12, 'stephentotilo': 12, 'jwhdavison': 3, 'benkuchera': 3, 'jeffgerstmann': 2, 'geoffkeighley': 4, 'thevowel': 1, 'notch': 1, 'manveerheir': 1, 'leighalexander': 7, 'nickchester': 3, 'joystiq': 1, 'gamingangel': 1, 'sidshuman': 1, 'arstechnica': 1, 'kobunheat': 3, 'wilw': 2, 'aegies': 2, 'godfree': 1, 'garnettlee': 1, 'patrickklepek': 1, 'johnnyminkley': 1, 'richard4481': 1, 'gamesdotcom': 1, 'gamasutra': 2, 'brentalfloss': 1, 'garywhitta': 1, 'giantbomb': 1, 'simoncarless': 1, 'radiomaru': 1, 'jamesmielke': 1, 'jimreilly': 1, 'mittense': 1, 'rdb_aaa': 1}
# {'robby1051': 3, 'engadget': 1, 'codinghorror': 1, 'notch': 1, 'wilw': 1, 'cnnbrk': 1, 'andrewpfister': 1}
# {'geoffkeighley': 2, 'seeson': 6, 'gamingangel': 11, 'radiomaru': 3, 'samversionone': 5, 'geekgirldiva': 2, 'therealcliffyb': 4, 'jbnet211': 1, 'weezul': 1}
# {}
# {}
# {}
# {}
# {'ladyluck34': 2, 'godfree': 6, 'yuriofwind': 5, 'ubisoft': 1, 'patrickklepek': 1, 'jeffgerstmann': 1, 'ps3nation': 4, 'evolvetom': 1, 'jeffcannata': 1, '2kgames': 2, 'stephentotilo': 1, 'fragdolls': 1, 'hiphopgamer': 2, 'kotaku': 1, 'therealcliffyb': 1, 'screwattack': 1, 'insomniacgames': 1, 'gameinformer': 1, 'otakuman5000': 1, 'gamepro': 1}
# {'nickchester': 18, 'colettebennett': 21, 'alibakes': 21, 'mikeyface': 4, 'keklar': 1, 'godfree': 1, 'jaredr': 1, 'maxscoville': 6, 'leighalexander': 4, 'garywhitta': 1, 'fragdolls': 1, 'weezul': 1, 'majornelson': 1, 'acarboni': 1, 'sidshuman': 1, 'jeffgerstmann': 1}
# {}
# {'thegame': 1}
# {}
# {}
# {'majornelson': 1, 'suckmyspork': 1, 'otakuman5000': 1, 'alibakes': 1, 'gameinformer': 1, 'joystiq': 1}
# {'edgeonline': 2, 'kotaku': 1, 'therealcliffyb': 3, 'majornelson': 2, 'mikeyface': 1, 'notch': 1}
# {'akirareiko': 2}
# {'stark': 22, 'colettebennett': 2, 'tinycartridge': 2, 'therealcliffyb': 1, 'notch': 8, 'kobunheat': 2, 'crecenteb': 1, 'matiasrivera': 3, 'the1console': 1}
# {'jamesmielke': 5, 'alex_navarro': 6, 'brentalfloss': 15, 'patrickklepek': 2, 'stephentotilo': 3, 'aegies': 7, 'fiddlecub': 1, 'taswell': 5, 'stillgray': 2, 'shoryukendotcom': 2, 'the_moviebob': 4, 'gamespite': 1, 'kobunheat': 1, 'leighalexander': 3, '1up': 3, 'therealcliffyb': 7, 'johntv': 1, 'iplaywinner': 3, 'justinmcelroy': 1, 'mudron': 1, 'acarboni': 1, 'anosou': 1, 'radiomaru': 1, 'jeffgerstmann': 2, 'jasonschreier': 1, 'nickhalme': 1}
# {'mlgpro': 9, 'ufc': 1, 'breakingnews': 1, 'engadget': 1}
# {'engadget': 7, 'metacritic': 2, 'guardiantech': 1}
# {}
# {'gamesajare': 2}
# {'brentalfloss': 34, 'wilw': 1, 'notch': 1, 'cnnbrk': 1}
# {'geekdotcom': 1, 'pushsquare': 14, 'britishgaming': 2, 'jake74': 6, 'patlike': 6, 'garywhitta': 1, 'popcap_games': 1, 'ultrabrilliant': 8, 'schillingc': 3, 'johnnyminkley': 2, 'gamespite': 1, 'the1console': 1, 'gamespotuk': 1, 'nowgamer_dave': 1, 'edgeonline': 1}
# {'praska': 1, 'mimachan': 1, 'bertrand_amar': 1, 'gamekult': 2}
# {'ufc': 6}
# {'bradgallaway': 2, 'notch': 2, 'radiomaru': 1, 'manveerheir': 1, 'adurdin': 1, 'kierongillen': 1, 'werezompire': 2}
# {'jamesdpaton': 2, 'chris_woodgate': 1, 'lisanorfolk': 1, 'mysonsspongemad': 1}
# {}
# {'robertflorence': 1, 'radiomaru': 1}
# {'sweetzilla': 2, 'lisanorfolk': 2, 'reviewanygame': 1}
# {}
# {'alex_navarro': 4, 'taswell': 4, 'alibakes': 4, 'the_ironsheik': 4, 'nickchester': 1, 'mikeyface': 4, 'jimreilly': 2, 'jwhdavison': 1, 'ctz': 1, 'andrew_reiner': 1, 'jasonschreier': 1, 'justinmcelroy': 1, 'gameinformer': 1}
# {'sidshuman': 2, 'popcap_games': 1, 'cutterbups': 2, 'otakuman5000': 11, 'notaxation': 1, 'metacritic': 1, 'robsellig': 1, 'ibu666': 1, 'snova34z': 1}
# {'slash_rick': 1, 'garotasgeeks': 1, 'popcap_games': 1}
# {'wilw': 1, 'gamecouch': 1}
# {'feitclub': 1, 'ukgamedeals': 1, 'dudey300': 4, 'shoptonet': 5, 'boomeranggames': 1}
# {'greencapt': 6, 'nasa': 1, 'majornelson': 1}
# {'zavvies': 20, 'ecetia': 2, 'elpixelilustre': 4, 'patlike': 1, 'akihabarablues': 1, 'clopezi': 1, 'reallopeor': 1}
# {}
# {'geoffkeighley': 1, 'theisb': 1}
# {'wondroushippo': 2, 'the1console': 1, 'razorianfly': 2, 'gameloft': 1, 'nickhalme': 1, 'gamestopcanada': 1, 'danawhite': 1, 'wilw': 1, 'tinycartridge': 1}
# {'leighalexander': 3, 'majornelson': 4, 'mikeyface': 8, 'goodgaming': 9, 'stillgray': 3, 'alex_navarro': 1, 'stephentotilo': 1, 'joystiq': 1, 'kweenie': 2, 'notch': 1, 'bradgallaway': 1, 'therealcliffyb': 9, 'patrickklepek': 1, 'andrewpfister': 1, 'geoffkeighley': 6, 'jeffgerstmann': 4, 'robertflorence': 1, 'crecenteb': 2, 'gamasutra': 1, 'cthagod': 1, 'redditpics': 1, 'gearboxsoftware': 1, '2kgames': 1, 'ferricide': 2, 'justinmcelroy': 1, 'giantbomb': 1, 'shoinan': 2, 'craigums': 1, 'jwhdavison': 2, 'hiphopgamer': 3, 'giordanobc': 1}
# {'therealcliffyb': 5, 'engadget': 2, 'angryjedi': 1, 'patrickklepek': 1, 'taswell': 1, 'garywhitta': 1, 'kewlrats': 6, 'stillgray': 2, 'joystiq': 5, 'infinite_ammo': 1, 'justinmcelroy': 1, 'werezompire': 5, 'wilw': 1, 'retroremakes': 1, 'ferricide': 2, 'cheeseplus': 1, 'gamasutra': 4, 'jimsterling': 1, 'manveerheir': 2, 'stephentotilo': 1, 'missiondeep': 2, 'thevowel': 1, 'majornelson': 1, 'megaran': 1, 'jeffgerstmann': 1}
# {'johnnyminkley': 21, 'robertsammons': 1, 'digital_foundry': 1, 'garywhitta': 2, 'kotaku': 1, 'notch': 1, 'uberguineapig': 1, 'edgeonline': 16, 'charltonbrooker': 1, 'majornelson': 2, 'nicholsonb': 1, 'eurogamer_net': 1, 'patlike': 1}
# {'technobuffalo': 1, 'notch': 1}
# {}
# {}
# {'hotukdeals': 6, 'lisanorfolk': 1, 'kierongillen': 1, 'notch': 1}
# {}
# {'chrisremo': 1, '_wotta': 2, 'fiddlecub': 1, 'adonisdemon': 4, 'slackerninja': 2, 'geoffkeighley': 1, 'stillgray': 1, 'shoptonet': 1, 'bethblog': 2, 'notaxation': 1}
# {'chibisake': 16, 'tecmokoeieurope': 4}
# {}
# {'capcom_unity': 2, 'toymachinesh': 6, 'stillgray': 1, 'jamesmielke': 1, 'rashanii': 1, 'otakuman5000': 3, 'magisterrex': 1, 'bradgallaway': 1, 'gamesasylum': 1}
# {}
# {}
# {'calz88': 1, 'ibu666': 30, 'a1dy74': 7, 'corporalkitty': 7, 'cutterbups': 11, 'darkangelrafael': 7, 'majornelson': 6, 'therealcliffyb': 2, '_wotta': 1, 'evilnoob': 1, 'ukgamedeals': 1, 'boomeranggames': 1, 'engadget': 1, 'thevowel': 1, 'guardiantech': 1}
# {'jaredr': 3, '1up': 1, '_wotta': 3, 'johntv': 1, 'jamesmielke': 1, 'psnstores': 3, 'speedbrkr': 3, 'tecmokoeieurope': 1, 'alongcamemary1': 2, 'shoryukendotcom': 4, 'jeffgerstmann': 3, 'kobunheat': 1, 'therealcliffyb': 1, 'iplaywinner': 2, 'andrewpfister': 1, 'filthierich': 1, 'harada_tekken': 1, 'geoffkeighley': 1, 'notaxation': 1, 'sterling_m': 1, 'kotaku': 1, 'reviewanygame': 1}
# {'britishgaming': 3, 'robertflorence': 17, 'atheistium': 1, 'ultrabrilliant': 7, 'leighalexander': 1, 'benkuchera': 1, 'ukgamedeals': 1, 'notch': 1, 'therealcliffyb': 1, 'patlike': 1, 'schillingc': 1}
# {'ewengcameron': 13, 'leducviolet': 4, 'wolfpupy': 3, 'moosegrinder': 3, 'robertflorence': 2, 'ultrabrilliant': 1}
# {'johncena': 1, 'joystiq': 1}
# {}
# {}
# {'izzynobre': 16, 'marcorigobelli': 1, 'lucasfresno': 2, 'jurandirfilho': 1, 'r0cc0': 6, 'geekpobre': 1, 'iltonjr': 5, 'filipekiss': 4, 'slash_rick': 4, 'fernando_x': 1, 'pedroaugusto': 1, 'bqeg': 2, 'renao': 1, 'kosmidis': 1, 'pabloprime': 1, 'utops': 1}
# {'samversionone': 6, 'justinmcelroy': 1, 'maxdyckhoff': 2, 'gamingangel': 8, 'therealcliffyb': 6, 'tromboneforhire': 5, 'godfree': 2, 'kweenie': 7, 'seeson': 5, 'popcap_games': 1, 'charltonbrooker': 1, 'joystiq': 1, 'leighalexander': 4, '360junkies': 2, 'capsulecomputer': 15, 'bakedant': 3, 'thevowel': 1, 'patrickklepek': 1, 'dudieboy': 1, '1up': 1, 'alex_navarro': 1, 'hiphopgamer': 1, 'wilw': 1, 'gamepro': 1}
# {'patlike': 41, 'eurogamer_net': 8, 'johnnyminkley': 25, '_wotta': 2, 'maxdyckhoff': 1, 'garywhitta': 6, 'majornelson': 1, 'geoffkeighley': 1, 'insomniacgames': 1, 'mike_acton': 3, 'hiphopgamer': 1, 'aegies': 1, 'gamasutra': 1, 'mega64official': 1}
# {}
# {'renzosh': 3, 'resetmx': 1}
# {'silverstar22b': 1}
# {}
# {'therealjuicyj': 4, 'the_ironsheik': 1}
# {'netsabes': 16, 'damonx': 4, 'engadget': 1, 'leyeti': 1, 'bertrand_amar': 1}
# {'therealcliffyb': 1, 'notaxation': 1}
# {'slickdeals': 1}
# {'engadget': 2, 'vikingvessel': 1, 'geekdotcom': 1, 'capsulecomputer': 3, 'wilw': 1}
# {'boomeranggames': 16, 'insertcointees': 3}
# {'ochocinco': 1}
# {'ryanpthompson': 4, 'crecenteb': 3, 'mlgpro': 3, 'jaredr': 1, 'iplaywinner': 3, 'atheistium': 2, 'potatohead': 1}
# {'metacritic': 5, 'razorianfly': 2, 'shoinan': 2, 'shoptonet': 1, 'schillingc': 1, 'wilw': 1, 'eurogamer_net': 8, 'edgeonline': 6, 'britishgaming': 3, 'arstechnica': 1, 'mittense': 1, 'radiomaru': 2, 'giantbomb': 2, 'gameinformer': 1}
# {'leighalexander': 4, 'majornelson': 8, 'seeson': 6, 'maxdyckhoff': 4, 'tromboneforhire': 2, 'sidshuman': 2, 'stepto': 1, 'justinmcelroy': 2, 'thevowel': 9, 'therealcliffyb': 2, 'ubisoft': 1, 'mdk2002': 1, 'acarboni': 2, 'jeffcannata': 1, 'gameinformer': 1, 'oneofswords': 4, 'fullbright': 1, 'notch': 2, 'godfree': 1, 'alibakes': 3}
# {'ghostbane': 2, 'ryanpthompson': 1, 'leducviolet': 1, 'tlarn': 3}
# {}
# {'robertflorence': 19, 'aceybongos': 1, 'majornelson': 5, 'ea': 1, 'edgeonline': 1, 'eurogamer_net': 1}
# {}
# {'arstechnica': 1}
# {'barifromsd': 1, 'msmorev': 3, 'capsulecomputer': 5, 'cnnbrk': 1, 'majornelson': 1, 'reviewanygame': 3}
# {'msmorev': 2, 'gameloft': 1, 'theonlinemom': 1, 'capsulecomputer': 13, 'thegamefanatics': 1}
# {'johnnyminkley': 9, 'thevowel': 1, 'koibraces': 1, 'boomeranggames': 5, 'reviewanygame': 12, 'the_ironsheik': 1, 'gameloft': 1, 'gamespotuk': 1, 'atheistium': 1, 'rampageddeath': 1, 'giantbomb': 1}
# {'boomeranggames': 6, 'theberrytastic': 3, 'atheistium': 2, 'robertflorence': 3, 'insertcointees': 1, 'shoptonet': 1, 'popcap_games': 3, 'majornelson': 5, 'codies': 1, 'thevowel': 1, 'thq': 1}
# {'ufc': 2, 'gameinformer': 2, '2kgames': 1, 'leighalexander': 1, 'ps3fanboy': 1, 'jeffgerstmann': 4, 'therealcliffyb': 4, 'giantbomb': 3, 'taswell': 6, 'peterocc': 2, 'kewlrats': 2, 'ladyluck34': 4, 'totalgaming': 1, 'godfree': 1, 'fiddlecub': 2, 'garywhitta': 1, 'hiphopgamer': 2, 'bakedant': 1, 'ubisoft': 1, 'missiondeep': 2, 'sony': 1, 'ryanpthompson': 2, 'daveoshry': 1, 'majornelson': 1, 'otakuman5000': 1, 'yamstersg': 1, 'engadget': 1, 'geekdotcom': 1}
# {'xsuperhan': 1, 'alibakes': 2, 'sonicalpha': 9, 'majornelson': 27, 'therealcliffyb': 6, 'atheistium': 2, 'crecenteb': 3, 'wilw': 2, 'garywhitta': 1, 'thevowel': 1, 'boomeranggames': 3, 'oneofswords': 1, 'downard23': 1, 'gameinformer': 1, 'mr_moobs': 1, 'kotaku': 2}
# {'marcorigobelli': 22, 'forastieri': 3, 'radiomaru': 2}
# {'majornelson': 2, 'popcap_games': 2, 'engadget': 5, 'tromboneforhire': 1, 'totalgaming': 1, 'crunchgear': 1, 'stroughtonsmith': 1, 'joystiq': 1, 'xbox_news': 1}
# {'2kgames': 1, 'gearboxsoftware': 1, 'majornelson': 1, 'boomeranggames': 1, 'machinima_com': 7}
# {'slickdeals': 1, 'keklar': 30, 'kancer': 19, 'louiedog': 4, 'kyaizen': 2, 'thegamefanatics': 1, 'majornelson': 2, 'boomeranggames': 2, 'godfree': 1, 'gamedealdaily': 1}
# {'godfree': 1, 'thesocialgamer': 1, 'majornelson': 12, 'therealcliffyb': 15, 'giantbomb': 1, 'gamingangel': 2, 'samversionone': 3, 'leighalexander': 2, 'ferricide': 1, 'otakuman5000': 13, 'joystiq': 1, 'fragdolls': 1, 'amazongames': 1, 'oldgamereviewer': 1, 'magisterrex': 3, 'jbnet211': 4, 'cutterbups': 2, 'gamasutra': 4, 'gameinformer': 5, 'arstechnica': 1, 'popcap_games': 1, 'notch': 1, '2kgames': 1, 'maxdyckhoff': 1}
# {'edgeonline': 1, 'gamesajare': 16}
# {}
# {}
# {}
# {'ihatequotes': 3, 'ufc': 1, 'gametrailers': 1}
# {'crecenteb': 1, 'stillgray': 2, 'stephentotilo': 1, 'therealcliffyb': 3, 'wesphillips': 1, 'leighalexander': 2, 'gameinformer': 1, '1up': 1, 'eurogamer_net': 2, 'insomniacgames': 1, 'jwhdavison': 1, 'colettebennett': 1, 'fiddlecub': 1}
# {'schillingc': 1, 'shoinan': 1, 'britishgaming': 1, 'ukgamedeals': 1, 'therealcliffyb': 1}
# {'drkwingduck': 1}
# {'darrenkerwin': 2, 'nintendoscene': 2, 'kotaku': 1, 'pushsquare': 1, 'gamesasylum': 1, 'schillingc': 1, 'sticktwiddlers': 1}
# {'bradgallaway': 10, 'evilnoob': 1, 'gamingangel': 2, 'insomniacgames': 1, 'gameinformer': 5, 'amazongames': 4, 'majornelson': 1, '1up': 87, 'arstechnica': 1, 'kotaku': 1, 'gamasutra': 5, 'joystiq': 1}
# {}
# {}
# {'mike_acton': 34, 'notch': 2, 'leighalexander': 1, 'codinghorror': 19, 'insomniacgames': 1, 'ja2ke': 1}
# {'wiirok': 2}
# {'joystiq': 3, 'giantbomb': 1, 'greenspeak': 2, 'kotaku': 1, 'wilw': 1, 'geoffkeighley': 10, 'gamestop': 1, 'capsulecomputer': 2, 'ochocinco': 2, 'ufc': 1, 'majornelson': 3, 'insomniacgames': 2, 'richard4481': 1, 'therealcliffyb': 4, 'seeson': 1, 'timseppala': 1, 'thegame': 1, 'evil_avatar': 1, 'stephentotilo': 1, 'gametrailers': 1}
# {'akirareiko': 10}
# {'gameinformer': 8, 'uniromsmaster': 1}
# {'ochocinco': 1, 'iamch0pper': 1}
# {}
# {'ngamer_mag': 1, 'therealcliffyb': 2, 'giordanobc': 1, 'garywhitta': 1, 'ja2ke': 1, 'notch': 1, 'ubisoft': 2, 'werezompire': 1}
# {'shoryukendotcom': 1, 'iplaywinner': 1}
# {}
# {'guardiantech': 1}
# {'5minutesformom': 4, 'engadget': 1, 'nasa': 2, 'kzarr': 1}
# {'pipomantis': 1}
# {'majornelson': 1}
# {'akirareiko': 1, 'earcos': 1}
# {'stillgray': 9, 'gameinformer': 1, 'elprezau': 1, 'mittense': 1, 'monaeltahawy': 1}
# {'monch3': 4, 'therealcliffyb': 1, 'choch3': 5, 'resetmx': 1, 'gammita': 2, 'robsainz': 1, 'tierragamer': 1, 'elangrymonkey': 2, 'hentei009': 1, 'spartan9216': 3, 'gamemastermx': 1}
# {'_habacuc': 1, 'memohiervas': 2, 'renzosh': 1}
# {'kroniksan': 1, 'engadget': 1, 'clopezi': 2, 'gamesajare': 3, 'vidaextra': 1}
# {'manveerheir': 1, 'bajopants': 4, 'scarlettjen': 1, 'paulverhoeven': 6, 'robertflorence': 1, 'elizabethdanger': 4, 'leighalexander': 1, 'stillgray': 5, 'serrels': 1}
# {'d0nfil0fi0': 73, 'matiasrivera': 4, 'vardoc1': 1}
# {'nasa': 1}
# {'andrewpfister': 5, 'gamespite': 3, 'gametrailers': 1, 'coldmilk': 1, 'kobunheat': 2, '1up': 18, 'jimreilly': 1, 'stephentotilo': 1, 'gameinformer': 8, 'jamesmielke': 1, 'alex_navarro': 1, 'marvel': 1, 'feitclub': 1, 'joystiq': 2, 'geoffkeighley': 2, 'mudron': 1}
# {'codemasters_jp': 1}
# {'retroremakes': 1, 'patlike': 10, 'alibakes': 1, 'atheistium': 2, 'aegies': 1, 'jimreilly': 1, 'benmeetsworld': 1}
# {}
# {'joystiq': 1, 'ctrlaltkill': 12, 'majornelson': 1, 'keklar': 6, 'toymachinesh': 1, 'fiddlecub': 1, 'godfree': 1, 'alibakes': 5, 'downsouthtigger': 5, 'ladyluck34': 1, 'kewlrats': 1, 'capsulecomputer': 53, 'werezompire': 1, 'timseppala': 3, 'gameloft': 1, 'thegamefanatics': 21, '2kgames': 3, 'louiedog': 1, 'ea': 3, 'notch': 1, 'bethblog': 1, 'boomeranggames': 2, 'bradgallaway': 1, '_wotta': 11, 'metacritic': 1, 'thq': 2, 'seeson': 1, 'kyaizen': 1}
# {'patlike': 1, 'johnnyminkley': 1, 'digital_foundry': 4}
# {'majornelson': 5, 'nasa': 1, 'therealcliffyb': 8, 'wilw': 1, 'sidshuman': 1, 'gameloft': 11, 'dittotweeto': 1, 'gameinformer': 1, 'engadget': 2, 'insomniacgames': 1, 'stephentotilo': 1, 'machinima_com': 3}
# {'evilnoob': 13, 'robertflorence': 1, 'majornelson': 4, 'insertcointees': 1, 'xstex': 1, 'boomeranggames': 2, 'lovefilm': 1, 'n4g': 1}
# {'moosegrinder': 5, 'xstex': 18, 'wideawakewesley': 1, 'johnnyminkley': 2, 'sonicalpha': 3, 'therealcliffyb': 1, 'demon_pigeon': 2, 'dudieboy': 2, 'charltonbrooker': 2}
# {'kobunheat': 5, 'sidshuman': 3, 'fullbright': 1, 'insomniacgames': 1, 'garywhitta': 1, 'amazongames': 1, 'arstechnica': 1, 'majornelson': 3, 'therealcliffyb': 1, 'patlike': 1}
# {'angryjedi': 3, 'nicholsonb': 1, 'leighalexander': 2, 'justinmcelroy': 6, 'manveerheir': 1, 'sidshuman': 1, 'jwhdavison': 1, 'droidmill': 1, 'slidetoplay': 1, 'nickchester': 1, 'gameinformer': 1, 'therealcliffyb': 1, 'joystiq': 1}
# {'demon_pigeon': 47, 'wolfpupy': 1}
# {'sterling_m': 2, 'rdb_aaa': 1, 'insomniacgames': 1, 'ferricide': 1, 'aegies': 2, 'johntv': 1, 'gamespite': 3, 'patrickklepek': 1, 'jeffcannata': 2}
# {'majornelson': 7, 'jeffgerstmann': 1, 'sergiodaprokkz': 4, 'gameinformer': 1, 'aots': 1, 'therealcliffyb': 2, 'geoffkeighley': 1}
# {}
# {}
# {'popcap_games': 1, 'cnnbrk': 1}
# {'slackerninja': 5, 'stroughtonsmith': 5, 'viticci': 1, 'christyxcore': 1}
# {'giantbomb': 9, 'iplaywinner': 16, 'justinmcelroy': 5, 'jeffgerstmann': 6, 'aegies': 3, 'nicholsonb': 5, 'nickchester': 4, 'aaronlinde': 4, 'mikeyface': 4, 'fiddlecub': 3, 'jaredr': 2, 'shoryukendotcom': 8, 'colettebennett': 4, 'sidshuman': 1, 'theisb': 1, '1up': 3, 'maxscoville': 1, 'therealcliffyb': 5, 'gamespite': 1, 'leighalexander': 1, 'taswell': 2, 'amazongames': 1, 'manveerheir': 1, 'insomniacgames': 1, 'the_moviebob': 1, 'kobunheat': 1, 'garywhitta': 1, 'amazondeals': 1, 'atheistium': 1}
# {'bethblog': 18, 'nickchester': 1, 'kotaku': 12, 'patrickklepek': 1, 'craigums': 1, 'theescapistmag': 1, 'wilw': 1, 'screwattack': 1, 'gametrailers': 3, 'gameinformer': 1, 'mega64official': 1, '1up': 2, 'pslifestyle': 1, 'eurogamer_net': 1, 'gamestop': 1, 'gamepro': 2}
# {'wilw': 4, '1up': 4, 'thebattleangel': 1, 'tinycartridge': 4, 'fortninety': 5, 'mega64official': 1, 'notch': 2, 'the_moviebob': 1, 'jasonschreier': 1}
# {}
# {}
# {'diplo': 4}
# {}
# {}
# {'ferricide': 9, 'cnnbrk': 1, 'mudron': 21, 'gamespite': 9, 'kobunheat': 13, 'johntv': 7, 'jamesmielke': 2, 'notaxation': 1, 'the1console': 1, 'mikeyface': 1, 'wilw': 2, 'shanewatch': 1, 'jasonschreier': 2, 'rdb_aaa': 3, 'theisb': 1, 'gamepro': 1, 'sterling_m': 1, 'majornelson': 1, 'capcom_unity': 1, 'leducviolet': 1, 'justinmcelroy': 1, '1up': 1, 'leighalexander': 1, 'edgeonline': 1, 'taswell': 1, 'jwhdavison': 1}
# {'didiraja': 2, 'majornelson': 1, 'pabloprime': 59, 'slash_rick': 29, 'walmart_games': 22, 'gameinformer': 2, 'jejepinheiro': 4, 'jogorama': 1, 'gamesenior': 1, 'mundowalmart': 1, 'naointendo': 1}
# {'manveerheir': 5, 'feitclub': 13, 'simoncarless': 4, 'jamesmielke': 12, 'leighalexander': 15, 'kobunheat': 6, 'rdb_aaa': 3, 'ultrabrilliant': 2, 'patrickklepek': 4, 'gamasutra': 4, 'therealcliffyb': 1, 'sidshuman': 1, 'johntv': 1, 'aegies': 1, 'garnettlee': 1, 'shanewatch': 1, 'chrisremo': 1, 'colettebennett': 1, 'geoffkeighley': 1, 'tinycartridge': 1, 'gamespite': 1, 'andrewpfister': 1, 'aaronlinde': 1, 'garywhitta': 2, 'sterling_m': 1}
# {'monch3': 4, 'choch3': 1}
# {'therealcliffyb': 1, 'gameinformer': 1, 'gamespite': 1, 'taswell': 2, 'aegies': 2, 'jeffgerstmann': 2, 'the_katbot': 1, 'alex_navarro': 1}
# {'izzynobre': 33, 'geekpobre': 10, 'r0cc0': 3, 'kosmidis': 1, 'tiagosantana': 1, 'pedroaugusto': 1, 'vyktorb': 1, 'marcorigobelli': 1}
# {'iplaywinner': 6, 'jaredr': 2, 'shoryukendotcom': 3, 'notch': 1, 'hiphopgamer': 2, 'brelston': 1, '1up': 1, 'majornelson': 1, 'gamesradar': 1}
# {'thegame': 1, 'therealcliffyb': 3, 'harryallen': 3}
# {}
# {'gamespotuk': 2, 'yamstersg': 1, 'eurogamer_net': 1, 'mdk2002': 2, 'codies': 1}
# {'majornelson': 1, 'redacao_nw': 1}
# {'tinycartridge': 5, 'fullbright': 1, 'stephentotilo': 5, 'johntv': 2, 'simoncarless': 1, 'acarboni': 2, 'patrickklepek': 2, 'jasonschreier': 2, 'adamatomic': 1, 'jamesmielke': 1, 'radiomaru': 1, 'danawhite': 1, 'stillgray': 1, 'the1console': 1, 'hiphopgamer': 1, 'fangamer': 2}
# {}
# {'ubisoft': 7, 'maxdyckhoff': 2, 'sergiodaprokkz': 1, 'majornelson': 4, 'sonicalpha': 1, 'craigums': 3, 'therealcliffyb': 2, 'alibakes': 5, 'louiedog': 1, 'arumi_kai': 2, 'downsouthtigger': 1, 'geoffkeighley': 1, 'wilw': 1, 'geekgirldiva': 1, 'mlgpro': 1, 'seeson': 2, 'mega64official': 1, 'thevowel': 1, 'gamestop': 1, 'gamingangel': 1}
# {'uberguineapig': 1}
# {'ryanpthompson': 57, 'zocialtv': 1}
# {'ochocinco': 2, 'thegame': 1}
# {}
# {'notch': 3, 'eurogamer_net': 2, 'notaxation': 1, 'insomniacgames': 1, 'insertcointees': 3, 'platinumgames': 1, 'gameinformer': 1}
# {'leighalexander': 18, 'alex_navarro': 1, 'chrisremo': 44, 'ja2ke': 19, 'manveerheir': 12, 'brainygamer': 2, 'antikewl': 1, 'wolfpupy': 3, 'eurogamer_net': 1}
# {'ihatequotes': 3}
# {}
# {'docsigma': 3, 'brentalfloss': 1, 'tlarn': 1, 'radiomaru': 2, 'yugiohtas': 2}
# {'crecenteb': 9, 'iplaywinner': 6, 'notch': 5, 'gamasutra': 1, '1up': 2}
# {'gamesenior': 7, 'wiiclube': 9, 'jejepinheiro': 1, 'gamespite': 1, 'tinycartridge': 1, 'nosgeeks': 6, 'pabloprime': 1, 'xboxplus': 1, 'roniuj': 1, 'rodrigoflausino': 1}
# {'wilw': 1}
# {'ferricide': 1, 'leighalexander': 2, 'nickhalme': 1, 'mike_acton': 1, 'therealcliffyb': 2}
# {}
# {'geekgirldiva': 4, 'magisterrex': 1, 'clickeric': 1, 'thevowel': 1}
# {}
# {}
# {'kancer': 1, 'otakuman5000': 2, 'downsouthtigger': 1, 'thevowel': 1}
# {'danryckert': 3, 'andrew_reiner': 2, 'jimreilly': 2, 'therealcliffyb': 1}
# {'patrickklepek': 1}
# {'songbirdeeee': 2, 'robertsammons': 1, 'sstaver': 1, 'stroughtonsmith': 1, '148apps': 1, 'gameloft_france': 2, 'inoone5326': 2, 'vikingvessel': 1, 'cobbiecollinge': 4, 'gamesdotcom': 1, 'cobraxcobrax': 1, 'kzarr': 3, 'msmorev': 1, 'momsfocus': 2, 'jamesdpaton': 1, 'dittotweeto': 3, 'dancer2712': 1, 'capsulecomputer': 1, 'lisanorfolk': 1}
# {'gameloft': 1}
# {'gameloft': 3, 'appticker': 2}
# {'gameloft': 5, 'iphonfr': 2, 'bertrand_amar': 4}
# {'gameloft': 7, 'guardiantech': 1}
# {'renzosh': 1, 'elpaella': 1}
# {}
# {}
# {'therealcliffyb': 2, 'craigums': 1, 'ochocinco': 1, 'fiddlecub': 1, 'guycocker': 1, 'ninetoez': 1, 'greenspeak': 1, 'capcom_unity': 1, 'gameinformer': 1, 'gamasutra': 1, 'majornelson': 1}
# {'notaxation': 85, 'teanah': 1, 'garywhitta': 3, 'jimreilly': 5, 'wilw': 1, 'therealcliffyb': 5, 'atheistium': 1, 'vimtocreed': 1, 'geoffkeighley': 1, 'gameinformer': 3, 'aegies': 1, 'sidshuman': 2, 'jeffgerstmann': 3, 'victor_lucas': 1, 'maxscoville': 1, 'gamespite': 1, 'gearboxsoftware': 1, 'ferricide': 1, 'richign': 4, 'stephentotilo': 1, 'insomniacgames': 1}
# {'fernando_x': 1, 'pabloprime': 1, 'slash_rick': 1, 'wiiclube': 2, 'bqeg': 1, 'revistaarkade': 1}
# {'gammita': 1, 'polux_3': 3, 'akirareiko': 1}
# {'jwhdavison': 2, 'angryjedi': 4, 'gameinformer': 2, 'majornelson': 2, 'rdb_aaa': 1, 'mrpointyhead': 1, 'oneofswords': 1, 'bethblog': 1, '2kgames': 1, 'ubisoft': 1, 'leighalexander': 1, 'gamesradar': 1, 'sony': 1}
# {'wideawakewesley': 1, 'geoffkeighley': 3, 'stephentotilo': 1, 'majornelson': 6, 'jimreilly': 1, 'therealcliffyb': 2, 'jeffcannata': 1, 'thevowel': 1, 'ja2ke': 1, 'gearboxsoftware': 1, 'goodgaming': 1}
# {'snova34z': 1, 'crhopkins': 1, 'therealcliffyb': 1}
# {}
# {'johncena': 1, 'therealcliffyb': 2, 'justinmcelroy': 2, 'insomniacgames': 1, 'majornelson': 2, 'amazongames': 1, 'toptweets': 1, 'crecenteb': 1, 'kotaku': 1, 'stephentotilo': 1}
# {}
# {'elpixelilustre': 4, 'akihabarablues': 2, 'vidaextra': 1}
# {'totalgaming': 3, 'eurogamer_net': 3, 'nintendo247': 1, 'edgeonline': 2, 'joystiqnintendo': 1, 'retroremakes': 1, '1up': 1, 'johnnyminkley': 1, 'britishgaming': 1, 'magisterrex': 1}
# {}
# {'giordanobc': 2, 'popcap_games': 2, 'gameinformer': 1, 'crecenteb': 1, 'bethblog': 1, 'stephentotilo': 1}
# {'fernando_x': 2, 'pabloprime': 10, 'gagagames': 8, 'redacao_nw': 3, 'wiiclube': 6, 'omelete': 2, 'xboxplus': 1, 'rodrigoflausino': 1, 'supernovo_net': 1, 'jejepinheiro': 1, 'gameloft': 1}
# {'ibere': 3, 'renao': 2, 'notch': 1, 'geoffkeighley': 1, 'jiguryo': 3, 'didiraja': 1, 'jimreilly': 1, 'gagagames': 1}
# {}
# {'kobunheat': 6, 'feitclub': 3, 'johntv': 7, 'mudron': 8, 'jamesmielke': 14, 'greenspeak': 1, 'shanewatch': 1, '1up': 12, 'ferricide': 3, 'rdb_aaa': 1, 'patrickklepek': 4, 'stillgray': 1, 'simoncarless': 1}
# {'fiddlecub': 1, 'guycocker': 37, 'insertcointees': 1, 'jwhdavison': 2, 'bethblog': 1, 'schillingc': 1, 'patlike': 1, 'notch': 3, 'darrenkerwin': 1, 'giantbomb': 1}
# {'gamespotuk': 1, 'platinumgames': 1, 'notch': 2, 'jwhdavison': 1, 'elizabethdanger': 2, 'fiddlecub': 1, 'jamesmielke': 1}
# {'adonisdemon': 1, 'cantista': 4, 'shoryukendotcom': 1, 'brelston': 4, 'ferricide': 1, 'setsuna_quanta': 1, 'cvg_uk': 1, 'ea': 1, 'wilw': 1, 'therealcliffyb': 1, 'insomniacgames': 1}
# {}
# {'drules2': 1}
# {'gameinformer': 1}
# {}
# {'geoffkeighley': 13, 'insomniacgames': 2, 'wondroushippo': 1, 'louiedog': 1, 'clopezi': 1, 'vimtocreed': 1, 'mega64official': 2, 'therealcliffyb': 6, 'ufc': 1, 'radiomaru': 1, 'joystiq': 1, 'godfree': 1, 'kobunheat': 1, 'majornelson': 1}
# {'majornelson': 17, 'godfree': 1, 'greenspeak': 1, 'thevowel': 11, 'seeson': 1, 'nickchester': 3, 'giordanobc': 5, 'stephentotilo': 8, 'mikeyface': 1, 'louiedog': 1, 'keklar': 2, 'manveerheir': 4, 'jwhdavison': 1, 'chrisremo': 1, 'jasonschreier': 2, 'hodapp': 2, '1up': 2, 'arstechnica': 1, 'benkuchera': 1, 'engadget': 1, 'patrickklepek': 1, 'bethblog': 1, 'insomniacgames': 1, 'thq': 1}
# {'edgeonline': 1}
# {'gearboxsoftware': 1, 'xbox_news': 1, 'fragdolls': 1, '2kgames': 1, 'notch': 1, 'ubisoft': 1, 'bradgallaway': 1}
# {'kweenie': 36, 'tromboneforhire': 1, 'weezul': 1, 'crixlee': 8, 'kewlrats': 1, 'peterocc': 1, 'leighalexander': 2, 'ladyluck34': 2, 'seeson': 2, 'gamesdotcom': 1, 'crecenteb': 1, 'sterling_m': 1, 'wondroushippo': 1, 'ryanpthompson': 1, 'patrickklepek': 1, 'geekgirldiva': 1, 'godfree': 2}
# {}
# {'catpow3r': 1, '_habacuc': 1, 'memohiervas': 1, 'engadget': 2, 'monch3': 8, 'earcos': 1}
# {'xav': 2, 'johntv': 6, 'andrewpfister': 14, 'patrickklepek': 7, 'alex_navarro': 1, 'jamesmielke': 5, 'jeffcannata': 12, 'geoffkeighley': 4, 'thevowel': 4, 'leighalexander': 4, 'ferricide': 8, 'rampage198': 1, 'jwhdavison': 6, 'justinmcelroy': 2, 'ratsoalbion': 2, 'majornelson': 1, 'kweenie': 4, 'sterling_m': 7, 'gamespite': 3, 'taswell': 2, 'shanewatch': 3, 'sidshuman': 2, 'kobunheat': 1, 'nickchester': 1, 'timseppala': 1, 'therealcliffyb': 1}
# {'borbs': 3}
# {'taswell': 21, 'patrickklepek': 2, 'wilw': 1, 'jeffgerstmann': 5, 'jwhdavison': 2, 'andrewpfister': 1, 'giantbomb': 2, 'justinmcelroy': 1, 'alex_navarro': 2, 'kobunheat': 1, 'therealcliffyb': 4, 'greenspeak': 1, 'notch': 1, 'ratsoalbion': 1}
# {}
# {'gtjio': 7, 'yugiohtas': 9, 'kylehebert': 3, 'breakingnews': 1, 'docsigma': 1, 'brentalfloss': 1, 'tinycartridge': 1}
# {'crecenteb': 2, 'mikeyface': 3, 'greencapt': 1, 'msmorev': 1, 'notch': 2, '1up': 1, 'therealcliffyb': 2, 'thevowel': 2, 'majornelson': 1, 'danryckert': 1, 'joystiq': 2, 'amazongames': 1, 'totalbiscuit': 1}
# {'cnnbrk': 1, 'nasa': 1}
# {}
# {'crixlee': 1, 'wilw': 1, 'kweenie': 2, 'thevowel': 4, 'radiomaru': 1}
# {'r0cc0': 9, 'filipekiss': 18, 'marcorigobelli': 15, 'slash_rick': 1, 'oimperador': 2, 'utops': 3, 'odametal': 2, 'tiagosantana': 1, 'caiocorraini': 1, 'notch': 2}
# {'elizabethdanger': 2, 'stillgray': 5, 'notch': 1}
# ...
# {'angryjedi': 12, 'feitclub': 12, 'asatiir': 4, '1up': 2, 'adamatomic': 1, 'arstechnica': 1, 'nintendotheory': 1, 'jeffgrubb': 1, 'patrickklepek': 1}
# {'brentalfloss': 1}
# {'jeyyounit11': 1}
# {'walmart_games': 2, 'mundowalmart': 1, 'pabloprime': 1}
# {'leyeti': 6, 'bertrand_amar': 1, 'netsabes': 5, 'pipomantis': 1, 'gamekult': 2, 'gameloft': 1, 'popcap_games': 1}
# {'capcom_unity': 1}
# {'gamasutra': 2, 'keklar': 1, 'eugaet_aux': 1, 'fannyvonfabulus': 1, 'dinaj': 2, 'nikibaby219': 2, 'saintsrow': 2, 'ufc': 4, 'jbhuskers': 1, 'grumpy1970': 1, 'wwegames': 10, 'jimsterling': 1, 'mdk2002': 1, 'geoffkeighley': 1, 'gameinformer': 2, 'majornelson': 1, 'darkhorsecomics': 1, 'gametrailers': 1, '1up': 1, 'joystiq': 1}
# {'eurogamer_net': 2, 'wwegames': 2, 'gameinformer': 4, 'ufc': 5, 'shoptonet': 1, 'gamespotuk': 3, 'saintsrow': 4, 'ryanpthompson': 1, 'danawhite': 1, 'majornelson': 2, 'digital_foundry': 1, 'britishgaming': 1, 'kierongillen': 1, 'patlike': 1}
# {'ninadouglas': 1, 'dannclan': 1, 'boomeranggames': 1}
# {'guardiantech': 1, 'geekgirldiva': 4, 'geekdotcom': 1, 'xbox_news': 1, 'gameinformer': 1, 'amazongames': 1, 'amazondeals': 1}
# {}
# {}
# {'didiraja': 1, 'r0cc0': 5, 'filipekiss': 7, 'vyktorb': 1, 'rodrigoflausino': 1, 'notch': 1, 'borbs': 1, 'geekpobre': 5, 'caiocorraini': 1, 'marcorigobelli': 2, 'gust_assumpcao': 1, 'izzynobre': 1, 'pedroaugusto': 1, 'walmart_games': 1}
# {'gammita': 1}
# {}
# {'sidshuman': 11, 'leighalexander': 4, 'andrew_reiner': 1, 'bradgallaway': 10, 'joystiq': 2, 'engadget': 1, 'mittense': 2, 'justinmcelroy': 16, 'feitclub': 4, 'arstechnica': 3, 'nickchester': 5, 'mudron': 2, 'therealcliffyb': 3, 'jamesmielke': 1, 'benkuchera': 2, 'edgeonline': 1, 'alex_navarro': 1, 'charltonbrooker': 1, 'cantista': 1, 'jeffgerstmann': 1, 'shanewatch': 1, 'nicholsonb': 1, 'jasonschreier': 5, 'jaredr': 1, '1up': 1, 'garywhitta': 1, 'aegies': 1, 'gamesradar': 2, 'thevowel': 1, 'seeson': 1}
# {'fortninety': 1, 'fiddlecub': 1, 'gamespite': 3, 'feitclub': 1, 'rdb_aaa': 3, 'kobunheat': 1, 'ferricide': 1, 'joystiq': 1, 'mudron': 1, 'garywhitta': 2, 'simoncarless': 1}
# {}
# {'docsigma': 27, 'ghostbane': 5, 'brentalfloss': 6, 'jeffcannata': 1, 'fangamer': 1, 'mega64official': 1}
# {'platinumgames': 2}
# {'gamasutra': 1, 'vidaextra': 2}
# {'vidaextra': 5, 'elpixelilustre': 6, 'zavvies': 2, 'earcos': 2, 'cnnbrk': 1, 'majornelson': 1, 'engadget': 4, 'tecmokoeieurope': 9, 'ecetia': 1}
# {'theisb': 1}
# {'elpixelilustre': 3, 'clopezi': 2, 'akihabarablues': 1, 'zavvies': 2, 'majornelson': 1, 'insomniacgames': 1, 'kochmedia_es': 1, 'revogamers': 1, 'gamesajare': 1}
# {'fatwalletdeals': 1}
# {'ochocinco': 2}
# {'gameinformer': 2, 'robertflorence': 6, 'gamasutra': 2, 'mittense': 1, 'geekgirldiva': 3, 'the1console': 6, 'brentalfloss': 1, 'therealcliffyb': 10, 'patrickklepek': 2, 'mike_acton': 1, 'aegies': 1, 'capsulecomputer': 1, 'kierongillen': 1, 'notch': 5, 'jaredr': 2, 'gailsimone': 1, 'britishgaming': 4, 'acarboni': 1, 'fullbright': 3, 'radiomaru': 1, 'manveerheir': 1, 'edgeonline': 1, 'gamestopcanada': 1, 'leighalexander': 2, 'jasonschreier': 1, 'ufc': 2, 'aots': 5, 'gameloft': 1, 'garywhitta': 4, 'asatiir': 1, 'danawhite': 1, 'jeffgerstmann': 3, 'hiphopgamer': 2, 'andrewpfister': 1, 'jimreilly': 2, 'mega64official': 1, 'gamingangel': 1, 'maxscoville': 1, 'chrisuk': 1, 'giantbomb': 3, 'primesuspect': 1, 'crecenteb': 1, 'gamespite': 5, '1up': 3, 'darrenkerwin': 1, 'jeffcannata': 2, 'nickhalme': 1, 'patlike': 1, 'taswell': 2, 'popcap_games': 3, 'ctrlaltkill': 1, 'shoptonet': 1, 'insomniacgames': 1, 'simoncarless': 1, 'bajopants': 1, 'nickchester': 1, 'alex_navarro': 1, 'ferricide': 1, 'godfree': 1, 'wilw': 2, 'fiddlecub': 1, 'colettebennett': 2, 'mikeyface': 4, 'toymachinesh': 1, 'majornelson': 1, 'iplaywinner': 1, 'shoryukendotcom': 1, 'crixlee': 1, 'peterocc': 1, 'johntv': 1, 'arstechnica': 1, 'sidshuman': 1, 'feitclub': 1}
# {'kierongillen': 4, 'wilw': 1}
# {'mcvonline': 1, 'playstationeu': 1, 'darkangelrafael': 2, 'edgeonline': 1}
# {'nickchester': 2, 'alex_navarro': 2, 'azuritereaction': 5, 'jeffgerstmann': 3, 'joystiq': 1, 'gameinformer': 2, 'therealcliffyb': 1, 'charltonbrooker': 1}
# {'celestialbeard': 1, 'leducviolet': 1}
# {'akirareiko': 1, 'alibakes': 1}
# {'majornelson': 2, 'therealcliffyb': 1, '1up': 1}
# {}
# {}
# {'guglelmo_90': 24, 'redgenhd': 31, 'psykokillervk': 24}
# {'seeson': 5, 'mdk2002': 3, 'crixlee': 3, 'gamingangel': 1, 'therealcliffyb': 1, 'thevowel': 1, 'maxdyckhoff': 1, 'kyaizen': 1, 'colettebennett': 1}
# {'vidaextra': 1}
# {}
# {'engadget': 3, 'arstechnica': 1, 'popcap_games': 2, 'joystiq': 1, 'appshopper': 1}
# {}
# {'peterocc': 1, 'yamstersg': 13, 'aceybongos': 1, 'insertcointees': 8, 'shoptonet': 2, 'bakedant': 1, 'johnnyminkley': 2, 'gameinformer': 1, 'achievementhunt': 1, 'eurogamer_net': 5, 'britishgaming': 1, 'majornelson': 7, 'stigquotes': 1, 'therealcliffyb': 4, 'thevowel': 3, 'boomeranggames': 57, 'geoffkeighley': 1, 'joystiq': 1}
# {'wideawakewesley': 4, 'johnnyminkley': 14, '_wotta': 3, 'gamasutra': 1, 'crecenteb': 9, 'edgeonline': 1, '1up': 2, 'stephentotilo': 1, 'aceybongos': 1, 'pushsquare': 1, 'kotaku': 1, 'eurogamer_net': 3, 'boomeranggames': 2, 'codemasters_jp': 2, 'playasia': 1}
# {'_wotta': 1, '2kgames': 1}
# {'danawhite': 2}
# {'pakikaka': 1, 'vocinojan': 1}
# {}
# {'watdoetcollin': 14, 'nielsthooft': 6, 'mjselvig': 1, 'gamasutra': 1, 'pocketgamer': 1, 'razorianfly': 1}
# {'amazongames': 2, 'iplaywinner': 1, 'majornelson': 8, 'engadget': 3, 'joystiq': 2, 'cnnbrk': 3}
# {'hiphopgamer': 1}
# {'ctrlaltkill': 1, '_wotta': 1, 'eugaet_aux': 2, 'radiomaru': 2, 'majornelson': 1, 'kotaku': 1, 'benkuchera': 1, 'therealcliffyb': 1}
# {'danawhite': 16, 'ufc_brasil': 1}
# {'ufc': 5, 'danawhite': 3, 'canalcombate': 1}
# {}
# {'calz88': 1}
# {}
# {'amazondeals': 2}
# {'atheistium': 2, 'demon_pigeon': 7, 'ferricide': 2, 'britishgaming': 2, 'schillingc': 6, 'johnnyminkley': 3, 'edgeonline': 2, 'colettebennett': 1, 'notch': 1, 'robertflorence': 1, 'eurogamer_net': 1, 'adurdin': 1}
# {}
# {'edgeonline': 1, 'ultrabrilliant': 1, 'xstex': 1, 'wilw': 1, 'thevowel': 1, 'ukgamedeals': 2}
# {'wiiclube': 1, 'mittense': 1, 'gamesdotcom': 1, 'toymachinesh': 1, 'omelete': 1, '2itterist': 1}
# {'caminante_x': 1, 'ps3maniac': 1, 'nachtnebel': 1}
# {'charltonbrooker': 4, 'mudron': 5, 'therealcliffyb': 1, 'guycocker': 1, 'gamespotuk': 1, 'patrickklepek': 1}
# {}
# {}
# {'jimreilly': 1, 'mittense': 1, 'seeson': 2, 'insomniacgames': 1, 'hiphopgamer': 2}
# {}
# {'ochocinco': 1}
# {'bqeg': 21, 'izzynobre': 32, 'marcorigobelli': 42, 'roniuj': 11, 'oimperador': 6, 'geekpobre': 3, 'odametal': 1}
# {'sweetzilla': 10, 'clareandtribe': 3, 'barifromsd': 1, 'boomeranggames': 1, 'dancer2712': 1, 'redroses4': 1, 'thunderbirdsgo': 1}
# {'stark': 1, 'matiasrivera': 3}
# {}
# {'jeffcannata': 8, 'therealcliffyb': 7, 'garnettlee': 1, 'patrickklepek': 2, 'xav': 1, 'stephentotilo': 1, 'sonyplaystation': 1, 'radiomaru': 1, 'garywhitta': 1, 'notch': 1, 'theisb': 1, 'agent_m': 1}
# {}
# {'brksedu': 57, 'cejbrasil': 10, 'zehonline': 2}
# {}
# {'majornelson': 4, 'popcap_games': 2}
# {'capsulecomputer': 126, 'reviewanygame': 33, 'gameloft': 12, 'gamestopcanada': 1}
# {'akihabarablues': 1}
# {'jeffgerstmann': 7, 'taswell': 8, 'geoffkeighley': 2, 'jimreilly': 2, 'auntiepixelante': 1, 'notaxation': 12, 'alex_navarro': 1, 'aegies': 5, 'acarboni': 1, 'insomniacgames': 3, 'ufc': 1, 'therealcliffyb': 7, 'maxscoville': 1, 'nicholsonb': 1, 'jimsterling': 1, 'brelston': 1, 'patlike': 1, 'nickchester': 1, 'danawhite': 3, 'crecenteb': 1, 'giantbomb': 1, 'notch': 1}
# {}
# {'appbank': 1, 'razorianfly': 2, 'ispazio': 6, 'robertsammons': 1, 'macstoriesnet': 12, 'stroughtonsmith': 3, 'tuaw': 1}
# {'jiguryo': 1, 'omelete': 2, 'mundowalmart': 2, 'walmart_games': 5, 'joystiq': 7, 'popcap_games': 1, 'edgeonline': 1, 'bqeg': 1, 'giantbomb': 1, 'gameinformer': 1, 'bethblog': 1}
# {}
# {'gameinformer': 4, 'saintsrow': 2, 'majornelson': 1, 'giantbomb': 1, 'geoffkeighley': 1, 'kewlrats': 2, 'eurogamer_net': 1}
# {'bajopants': 2, 'stevivor': 1, 'johntv': 1, 'kobunheat': 1}
# {}
# {'borbs': 5, 'omelete': 1, 'oimperador': 1}
# {'kweenie': 3, 'toymachinesh': 3, 'kewlrats': 4, 'magisterrex': 1, 'otakuman5000': 7, 'rashanii': 1, 'manveerheir': 1, 'oldgamereviewer': 1, 'primesuspect': 2, 'stillgray': 1, 'majornelson': 9, 'thevowel': 1, 'wilw': 1, 'ctrlaltkill': 1, 'gamespotuk': 1, 'popcap_games': 1, 'timseppala': 1, 'ochocinco': 1, '_wotta': 1}
# {'bqeg': 7, 'r0cc0': 16, 'ibere': 10, 'utops': 1, 'izzynobre': 1, 'renao': 1}
# {'jogobarato': 1, 'redacao_nw': 6, 'naointendo': 2, 'zanfa': 2, 'garotasgeeks': 1}
# {}
# {'tromboneforhire': 2, 'thevowel': 1, 'therealcliffyb': 2, 'ochocinco': 4, 'kyaizen': 1, 'gameloft': 1, 'gamestopcanada': 1}
# {'garotasgeeks': 1, 'fernando_x': 1, 'mundowalmart': 21, 'jogobarato': 1}
# {'guycocker': 3, 'robertflorence': 1, 'atheistium': 2, 'joystiq': 1, 'therealcliffyb': 1, 'charltonbrooker': 1, 'chrisuk': 1, 'majornelson': 1}
# {'atheistium': 1, 'taswell': 1, 'majornelson': 3, 'fiddlecub': 1, 'psnstores': 9, 'geoffkeighley': 4, 'jaredr': 1, 'ferricide': 1, 'jimreilly': 3, 'kobunheat': 2, 'jamesmielke': 1, 'toymachinesh': 1, 'fortninety': 1, 'hodapp': 1}
# {'twotribesgames': 2, 'nielsthooft': 3, 'stephentotilo': 3, 'gamasutra': 1}
# {}
# {'therealcliffyb': 7, 'sergiodaprokkz': 1, 'xbox_news': 1}
# {}
# {'gamingangel': 9, 'peterocc': 6, 'crixlee': 4, 'mdk2002': 16, 'ladyluck34': 4, 'seeson': 6, 'godfree': 3, 'sergiodaprokkz': 10, 'otakuman5000': 2, 'greenspeak': 1, 'tromboneforhire': 1}
# {'theshums': 1, 'thevowel': 1, 'joystiq': 1, 'the_katbot': 1, 'jasonschreier': 3, 'angryjedi': 1, 'patrickklepek': 1, 'benkuchera': 1, 'notch': 1}
# {'ryanpthompson': 62, 'robby1051': 6, 'magisterrex': 1, 'gamepro': 1, 'zocialtv': 1}
# {'geekpobre': 1}
# {'seeson': 2, 'nickchester': 3, 'arstechnica': 1, 'sidshuman': 6, 'stephentotilo': 3, 'hiphopgamer': 1, 'gameovergreggy': 1, 'crecenteb': 3, 'andrewpfister': 3, 'gameinformer': 2, 'patrickklepek': 2, 'sterling_m': 2, 'therealcliffyb': 9, 'justinmcelroy': 1, 'aaronlinde': 1, 'insomniacgames': 1, 'geoffkeighley': 1, 'capcom_unity': 1, 'gamespite': 1, '1up': 1}
# {'markknoller': 3, 'cnnbrk': 1}
# {}
# {'cthagod': 1}
# {'evilnoob': 3, 'ukgamedeals': 5, 'jeffcannata': 10, 'majornelson': 2, 'engadget': 1, 'charltonbrooker': 1, 'glinner': 1}
# {'taswell': 18, 'jaredr': 1, 'leighalexander': 11, 'kewlrats': 10, 'mudron': 2, 'jwhdavison': 2, 'wondroushippo': 2, 'crixlee': 1, 'ferricide': 1, 'jeffgerstmann': 8, 'stephentotilo': 1, 'garywhitta': 1, 'jamesmielke': 8, 'rdb_aaa': 1, 'therealcliffyb': 3, 'gamespite': 1, 'aegies': 2, 'gamingangel': 2, 'andrewpfister': 3, 'patrickklepek': 1, 'giantbomb': 1, 'geoffkeighley': 1, 'slickdeals': 1, 'shoinan': 1, 'nickchester': 1, 'alex_navarro': 1}
# {'gagagames': 1, 'nosgeeks': 1, 'redacao_nw': 7, 'supernovo_net': 2, 'gamesenior': 4, 'xboxplus': 1}
# {}
# {'dudieboy': 1}
# {}
# {}
# {}
# {}
# {}
# {'patlike': 1, 'ultrabrilliant': 7, 'britishgaming': 8, 'shoinan': 2, 'robertflorence': 5, 'angryjedi': 4, 'therealcliffyb': 4, 'maxdyckhoff': 5, 'majornelson': 1, 'jwhdavison': 1, 'schillingc': 2, 'wilw': 2, 'atheistium': 4, 'notch': 1, 'eurogamer_net': 1, 'aaronlinde': 1, 'kobunheat': 1, 'jasonschreier': 1}
# {'slickdeals': 3, 'majornelson': 1}
# {'thevowel': 3, 'garywhitta': 1, 'mikeyface': 2}
# {'gameinformer': 2, 'stephentotilo': 1, 'theshums': 2, 'ea': 1, 'therealcliffyb': 3, 'louiedog': 1, 'crecenteb': 2, 'stillgray': 1, 'kierongillen': 1, 'greenspeak': 1, 'majornelson': 1, 'jeffgerstmann': 1, 'notch': 1}
# {'the_ironsheik': 3, 'leducviolet': 1}
# {'radiomaru': 2, 'gamingangel': 1}
# {}
# {}
# {'technobuffalo': 1, 'macstoriesnet': 1, 'razorianfly': 3, 'robertsammons': 20, 'hodapp': 3}
# {'danawhite': 1, 'johncena': 1, 'thq': 1}
# {'danawhite': 1, 'johncena': 4, 'wwegames': 2}
# {'pipomantis': 1, 'gamasutra': 1, 'leyeti': 8, 'gamekult': 8, 'netsabes': 5}
# {'therealcliffyb': 4, 'stephentotilo': 2, 'geoffkeighley': 2, 'mike_acton': 1, 'gameinformer': 1, 'joystiq': 1, 'patrickklepek': 1, 'justinmcelroy': 2}
# {'shoinan': 14, 'ratsoalbion': 6, 'bradgallaway': 6, 'fullbright': 1, 'joystiq': 1, 'shoptonet': 3, 'insertcointees': 3, 'johnnyminkley': 1, 'britishgaming': 2, 'metacritic': 1, 'edgeonline': 5, 'ukgamedeals': 1, 'eurogamer_net': 1, 'digital_foundry': 1, 'mcvonline': 1, 'charltonbrooker': 2, 'taswell': 1, 'arstechnica': 1, 'engadget': 1, 'guardiantech': 1, 'giantbomb': 2}
# {'joystiq': 7, 'jeffcannata': 25, 'jeffgerstmann': 3, 'taswell': 5, 'nickhalme': 2, 'danryckert': 1, 'sidshuman': 3, 'stephentotilo': 1, 'justinmcelroy': 1, 'fiddlecub': 1, 'jasonschreier': 1, 'kewlrats': 2, 'nickchester': 1, 'notch': 1, 'garnettlee': 4, 'jwhdavison': 3, 'geoffkeighley': 1, 'patrickklepek': 1}
# {'therealcliffyb': 1, 'ubisoft': 1, 'majornelson': 1}
# {'joystiq': 2, 'majornelson': 3, 'geoffkeighley': 1}
# {}
# {}
# {}
# {}
# {'majornelson': 4, 'hentei009': 1, 'louiedog': 1, 'jadw': 1, 'monch3': 1, 'therealcliffyb': 1}
# {'gameinformer': 1, 'nadygames': 1, 'rodrigoflausino': 4, 'gagagames': 3, 'redacao_nw': 2, 'wiiclube': 6, 'revistaarkade': 1, 'gamesenior': 3, 'garotasgeeks': 1, 'supernovo_net': 1, 'tiagosantana': 1, 'walmart_games': 1}
# {}
# {}
# {'otakuman5000': 5, 'majornelson': 1, 'oldgamereviewer': 2, 'insomniacgames': 1}
# {'aegies': 1, 'theisb': 1, 'jhonenv': 1}
# {}
# {'majornelson': 27, 'eurogamer_net': 5, 'thevowel': 1, 'godfree': 2, 'seeson': 4, 'atheistium': 5, 'wanyal': 8, 'crecenteb': 1, 'lonosg': 1, '1up': 1, 'johnnyminkley': 10, 'mdk2002': 2, 'tromboneforhire': 1, 'samversionone': 1, 'guycocker': 1, 'patlike': 5, 'jeffgerstmann': 1, 'robertflorence': 2, 'calz88': 1, 'joystiq': 1, 'mikeyface': 2, 'mudron': 2, 'therealcliffyb': 16, 'schillingc': 1, 'geoffkeighley': 8, 'patrickklepek': 1, 'edgeonline': 2, 'ultrabrilliant': 1, 'popcap_games': 2, 'capsulecomputer': 22, 'capcom_unity': 1, 'goodgaming': 1, 'gameinformer': 1, 'chrisuk': 2, '_wotta': 4, 'jaredr': 1, 'boomeranggames': 2, 'platinumgames': 1}
# {}
# {'louiedog': 2, 'downsouthtigger': 4, 'eugaet_aux': 1, 'memohiervas': 27, 'majornelson': 1, 'hentei009': 1}
# {}
# {}
# {'shoptonet': 2, 'itechgamer101': 1, 'majornelson': 1, 'bethblog': 1, 'capcom_unity': 1}
# {'majornelson': 1}
# {'therealcliffyb': 10, 'majornelson': 7, 'notch': 9, 'kotaku': 1, 'gamasutra': 2, 'machinima_com': 1, 'siliconera': 1, 'thevowel': 1, 'mlgpro': 2, 'joystiq': 2, 'peterocc': 1}
# {'gamespotuk': 1, 'hiphopgamer': 3, 'samversionone': 4, 'ninetoez': 4, 'thedcd': 1, 'dragoneez': 1, 'anjelusx': 1, 'otakuman5000': 1, 'crixlee': 1, 'seeson': 1, 'kweenie': 1, 'therealcliffyb': 1, 'ufc': 2, 'cnnbrk': 1, 'aegies': 1, 'danawhite': 1}
# {'machinima_com': 18}
# {'johnnyminkley': 12, 'britishgaming': 5, 'patlike': 5, '_wotta': 5, 'godfree': 1, 'giantbomb': 1, 'pikminguts92': 1, 'peterocc': 4, 'radiomaru': 1, 'thqinsider': 1, 'alex_navarro': 1, 'calz88': 1, 'eurogamer_net': 1, 'atheistium': 2, 'boomeranggames': 2, 'codies': 1}
# {'notch': 3, 'therealcliffyb': 2}
# {'notaxation': 1, 'richard4481': 4, 'eurogamer_net': 1, 'insomniacgames': 1, '_wotta': 1}
# {'majornelson': 2, 'higabeam': 1, 'innocentwalls': 11}
# {'gtjio': 1, 'joshjepson': 1}
# {}
# {'momimist': 1, 'innocentwalls': 1}
# {'kirbopher': 1, 'kylehebert': 1}
# {}
# {}
# {'taswell': 1, 'shoryukendotcom': 1, 'yugiohtas': 2, 'kotaku': 1, 'ctrlaltkill': 3, 'giantbomb': 1}
# {'r0cc0': 1, 'bqeg': 2, 'izzynobre': 1}
# {}
# {'maxdyckhoff': 6, 'thevowel': 2, 'popcap_games': 2, 'amazongames': 1, 'wilw': 3, 'majornelson': 2, 'seeson': 1, 'aots': 1, 'therealcliffyb': 1, 'gamingangel': 2, 'fragdolls': 1}
# {'yugiohtas': 1, 'mega64official': 1, 'kylehebert': 2}
# {'cejbrasil': 28, 'nadygames': 2, 'brksedu': 7}
# {'jeffgerstmann': 2, 'chachisays': 1, 'smoshanthony': 1}
# {'notch': 1}
# {}
# {}
# {}
# {'mdk2002': 1, 'majornelson': 2, 'therealcliffyb': 3, 'thegame': 2}
# {}
# {}
# {}
# {'ufc': 1, 'the_ironsheik': 1}
# {'renzosh': 2}
# {}
# {'majornelson': 1}
# {'insertcointees': 1}
# {'akirareiko': 3, 'majornelson': 1, 'platinumgames': 2, 'renzosh': 2}
# {'shoptonet': 11, 'therealcliffyb': 3, 'patlike': 16, 'aceybongos': 1, 'pesbrasil': 1, 'ibu666': 1, 'yamstersg': 1, 'kobunheat': 1, 'seedy87': 1, 'richard4481': 4, 'britishgaming': 1, 'johnnyminkley': 2, 'eurogamer_net': 1}

# %% [markdown]
# ---

# %% [markdown]
# Ignore this, it's only here to make the page pretty:

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# /*
# Placeholder for custom user CSS
#
# mainly to be overridden in profile/static/custom/custom.css
#
# This will always be an empty file in IPython
# */
# <style>
#     @import url(http://fonts.googleapis.com/css?family=Roboto:400,300,300italic,400italic,700,700italic);
#
#     div.cell{
#         font-family:'roboto','helvetica','sans';
#         color:#444;
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#
#     div.text_cell_render{
#         font-family: 'roboto','helvetica','sans';
#         line-height: 145%;
#         font-size: 120%;
#         color:#444;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Menlo", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# ---

# %% [markdown]
# <p><small><a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Python Programming for the Humanities</span> by <a xmlns:cc="http://creativecommons.org/ns#" href="http://fbkarsdorp.github.io/python-course" property="cc:attributionName" rel="cc:attributionURL">http://fbkarsdorp.github.io/python-course</a> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>. Based on a work at <a xmlns:dct="http://purl.org/dc/terms/" href="https://github.com/fbkarsdorp/python-course" rel="dct:source">https://github.com/fbkarsdorp/python-course</a>.</small></p>
